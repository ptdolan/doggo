# %%
import random 
import numpy as np
import scipy as sp
import pandas as pd
from multiprocessing import Pool
from statsmodels.stats.multitest import multipletests as mult  #MULTIPLE TESTING MODULE 
from matplotlib import pyplot as plt

# %%
MaxReps=100000

# %%
#'''
file="/Users/dolanpt/GitHub/doggo/msigdb.v7.1.symbols.gmt"#CHANGE THIS TO YOUR LOCATION. RUN BLOCK ONCE (to make pickles) THEN COMMENT OUT. 
with open(file,'r') as inf:
    alllines=[line.strip().split("\t") for line in inf]
    DF=pd.concat([pd.DataFrame(zip([l[0]]*len(l[2:]),l[2:]),columns=["term","genes"]) for l in alllines])
pd.to_pickle(DF,"/Users/dolanpt/GitHub/doggo/msigdb.pkl")#'''

# %%
MSigDB=pd.read_pickle("/Users/dolanpt/GitHub/doggo/msigdb.pkl")#CHANGE TO YOUR LOCALE (MATCH ABOVE)

# %%
#This inputData file should be a long table with genes as rows and the data for each as columns. The 'score' (e.g. Fold change, expression, z-scores,...) can then be 
inputData="/Users/dolanpt/GitHub/Sigal_Kallisto/iMos_gene_aggregate_tpm_grouped.csv"
data=pd.read_csv(inputData)
data
# Out:
#                     ens_gene  A2 WT-naive  C3 WT-naive  A1 WT-GFP-  \
# 0      ENSMUSG00000026621.13     0.859857     0.000000    0.000000
# 1      ENSMUSG00000036469.16   118.067398   108.629593  106.452823
# 2       ENSMUSG00000073481.9    71.644062    69.069683   56.722994
# 3      ENSMUSG00000079557.11    40.940105    37.265042   16.601162
# 4      ENSMUSG00000032656.14     3.309735     1.595721    4.675027
# ...                      ...          ...          ...         ...
# 36448  ENSMUSG00000034645.14     0.295178     0.000000    0.109467
# 36449   ENSMUSG00000034636.9    13.287938     7.371821    7.819896
# 36450  ENSMUSG00000029860.16   228.845024   194.823743  401.528683
# 36451  ENSMUSG00000055670.14    42.978379    20.241768   22.743517
# 36452  ENSMUSG00000039068.16    27.824590    27.262488   26.062940
#
#        C2 WT GFP-  E1 WT  GFP-  G2 WT GFP-  B1-WT GFP+  D2 WT-GFP+  \
# 0        0.000000     0.000000    0.000000    0.000000    0.000000
# 1      129.434172   109.525785  138.893886   12.825254   18.218114
# 2       48.778823    48.106826   56.128277   10.594809    9.221860
# 3       22.472490    18.061797   48.596196   15.540209   37.270784
# 4        1.789119     2.604040    0.606861    5.615579    0.340386
# ...           ...          ...         ...         ...         ...
# 36448    0.000000     0.000000    0.000000    0.000000    0.000000
# 36449    8.820467     6.482175    8.036890    5.935554    0.569044
# 36450  385.232075   368.648084  481.060299   14.732174   14.870812
# 36451   32.403302    25.599145   22.527851   13.546727   45.706051
# 36452   23.720083    26.949951   23.666496   21.493861  129.274013
#
#        F1 WT-GFP+  ...  A3-IFNgR GFP-  G1-IFNgR GFP-  B3 IFNgR GFP+  \
# 0        0.183826  ...       0.000000       0.626942       0.506929
# 1       29.793624  ...     117.329794     115.802546      39.794353
# 2       17.324734  ...      66.971091      72.972110      20.495282
# 3       24.123040  ...      14.813996      36.824349      16.209814
# 4        1.795046  ...      12.990403       3.828737       3.122841
# ...           ...  ...            ...            ...            ...
# 36448    0.000000  ...       0.000000       0.000000       0.000000
# 36449   12.266320  ...      10.983913      13.216390       6.864124
# 36450   65.275835  ...     248.095754     276.541543      66.838668
# 36451   27.491644  ...      32.387465      42.543486      18.052689
# 36452   37.424613  ...      54.788401      35.939438      48.492477
#
#        H1 IFNgR GFP+  D3 IFNAR-naive  H3 IFNAR-naive  C1 IFNAR -GFP-  \
# 0           0.000000        0.000000        0.000000        0.000000
# 1          24.198082       71.270946       87.812828       72.781772
# 2           7.216334       47.348194       61.873705       52.463231
# 3          59.866378       23.955406       31.135648       22.998625
# 4           2.708691        0.943470        1.590874        4.121986
# ...              ...             ...             ...             ...
# 36448       0.000000        0.000000        0.000000        0.000000
# 36449      43.321085       14.378782       12.148924       12.075700
# 36450      29.875020      194.607789      264.280036      425.446340
# 36451      59.201131       61.726350       29.358186       24.072036
# 36452     107.759275       50.728183       23.288795       35.888798
#
#        E2 IFNAR -GFP-  D1 -  IFNAR GFP+  F2 - IFNAR -GFP+
# 0            0.324218          0.692138          0.000000
# 1           94.233462         29.010021         38.041670
# 2           56.170955         24.130759         13.595724
# 3           32.771105         42.675506         17.851902
# 4            4.491177         10.451713          3.785896
# ...               ...               ...               ...
# 36448        0.000000          0.000000          0.000000
# 36449        8.169068         17.074305          7.559698
# 36450      421.228358         89.482323         77.707763
# 36451       26.063681         36.882354         19.554125
# 36452       25.153412         59.352488         29.674291
#
# [36453 rows x 23 columns]

# %%
def computeEnrichmentPV(t,d,P):#I had to write two nearly identical functions for this specific data set ("...PV", and "...CVB")
    DBgenes=MSigDB.loc[MSigDB.term==t].genes
    totalMean=d.loc[(d.Param==P)].mean_PV.values.mean()
    targets=d.loc[(d.Param==P)&([(d in DBgenes.values) for d in d.target.values])]
    nrowS=targets.shape[0]
    if nrowS>2:#If more that two genes in term set...
        print(t)
        meanSelect=totalMean-targets.mean_PV.values.mean()
        nrowT=d.shape[0]
        positives=0
        denom=0
        if meanSelect < 0:#choose which tail to test...
            while (positives<30)&(denom<MaxReps):
                denom+=1
                diffSample=totalMean-d.iloc[np.random.randint(0,nrowT,nrowS)].mean_PV.mean()
                positives+=int(diffSample<meanSelect)
        else:
            while (positives<30)&(denom<MaxReps):
                denom+=1                
                diffSample=totalMean-d.iloc[np.random.randint(0,nrowT,nrowS)].mean_PV.mean()
                positives+=int(diffSample>meanSelect)
        #print(positives/denom)
        #print((meanSelect-totalMean)/totalMean)
    else:return(1.0)
    return([positives/denom, ((meanSelect-totalMean)/totalMean)])

# %%
def computeEnrichmentCVB(t,d,P):
    DBgenes=MSigDB.loc[MSigDB.term==t].genes
    totalMean=d.loc[(d.Param==P)].mean_CVB.values.mean()
    targets=d.loc[(d.Param==P)&([(d in DBgenes.values) for d in d.target.values])]
    nrowS=targets.shape[0]
    if nrowS>2:
        print(t)
        meanSelect=totalMean-targets.mean_CVB.values.mean()
        nrowT=d.shape[0]
        positives=0
        denom=0
        if meanSelect < 0:#choose which tail to test...
            while (positives<30)&(denom<MaxReps):
                denom+=1
                diffSample=totalMean-d.iloc[np.random.randint(0,nrowT,nrowS)].mean_CVB.mean()
                positives+=int(diffSample<meanSelect)
        else:
            while (positives<30)&(denom<MaxReps):
                denom+=1                
                diffSample=totalMean-d.iloc[np.random.randint(0,nrowT,nrowS)].mean_CVB.mean()
                positives+=int(diffSample>meanSelect)
        #print(positives/denom)
        #print((meanSelect-totalMean)/totalMean)
    else:return(1.0)
    return([positives/denom, ((meanSelect-totalMean)/totalMean)])

# %%
PREFIX="REACTOME_"#DB to explore for enrichment (see the DB file for other formats "GO_", others...)

# %%
#This is the main block, and needs to be edited based on your data and the parameter (score column you will be sampling in your data.)
def f(term):
    DF=pd.DataFrame([term,computeEnrichmentPV(term,data,"Max")],index=["term","pBS"]).transpose() #A lot going on here. run the f() function defined above, take outputs and transpose for stacking in output DF
    return(DF)
if __name__ == '__main__':#Wrapped this f() function in a parallelization to speed up. Can tune pool size for computer. 
    with Pool(5) as p:
        PVMax=pd.concat(p.map(f, [term for term in MSigDB.term.unique() if term.startswith(PREFIX)]))
    PVMax['adjPbs']=mult(PVMax.pBS)[1]#
    PVMax.to_csv("PVMax.csv")#name output file approriately

# %%
if __name__ == '__main__':#Wrapped this f() function in a parallelization to speed up. Can tune pool size for computer. 
    with Pool(5) as p:
        PVMax=pd.concat(p.map(f, [term for term in MSigDB.term.unique() if term.startswith(PREFIX)]))
    PVMax['adjPbs']=mult(PVMax.pBS)[1]#
    PVMax.to_csv("PVMax.csv")#name output file approriately

# %%
def f(term):#max output based analysis CVB
    DF=pd.DataFrame([term,computeEnrichmentCVB(term,data,"Max")],index=["term","pBS"]).transpose() 
    return(DF)
if __name__ == '__main__':
    with Pool(5) as p:
        CVBMax=pd.concat(p.map(f, [term for term in MSigDB.term.unique() if term.startswith(PREFIX)]))
    CVBMax['adjPbs']=mult(CVBMax.pBS)[1]#p adjustment
    CVBMax.to_csv("CVBMax.csv")

# %%
def f(term):#midpoint based analysis PV
    DF=pd.DataFrame([term,computeEnrichmentPV(term,data,"MP")],index=["term","pBS"]).transpose() 
    return(DF)
if __name__ == '__main__':
    with Pool(5) as p:
        PVMP=pd.concat(p.map(f, [term for term in MSigDB.term.unique() if term.startswith(PREFIX)]))
    PVMP['adjPbs']=mult(PVMP.pBS)[1]
    PVMP.to_csv("PVMP.csv")

# %%
def f(term):#midpoint based analysis CVB
    DF=pd.DataFrame([term,computeEnrichmentCVB(term,data,"MP")],index=["term","pBS"]).transpose() 
    return(DF)
if __name__ == '__main__':
    with Pool(5) as p:
        CVBMP=pd.concat(p.map(f, [term for term in MSigDB.term.unique() if term.startswith(PREFIX)]))
    CVBMP['adjPbs']=mult(CVBMP.pBS)[1]
    CVBMP.to_csv("CVBMP.csv")
