# %%
# !pip3 install numpy
# !pip3 install scipy
# !pip3 install pandas
# !pip3 install multiprocessing
# !pip3 install statsmodels
# !pip3 install matplotlib

import random 
import numpy as np
import scipy as sp
import pandas as pd
from multiprocessing import Pool
from statsmodels.stats.multitest import multipletests as mult  #MULTIPLE TESTING MODULE 
from matplotlib import pyplot as plt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (1.26.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scipy in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from scipy) (1.26.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (2.1.3)
# Requirement already satisfied: numpy<2,>=1.22.4 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting multiprocessing
#   Using cached multiprocessing-2.6.2.1.tar.gz (108 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [7 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/kk/1fzwcqps6dd_3dt2hsjct0tr_85vzj/T/pip-install-d27i7lti/multiprocessing_cb6289123434458c8a795fa0eb35509d/setup.py", line 94
#           print 'Macros:'
#                 ^
#       SyntaxError: Missing parentheses in call to 'print'. Did you mean print('Macros:')?
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: statsmodels in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (0.14.0)
# Requirement already satisfied: numpy>=1.18 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from statsmodels) (1.26.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from statsmodels) (1.11.4)
# Requirement already satisfied: pandas>=1.0 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from statsmodels) (2.1.3)
# Requirement already satisfied: patsy>=0.5.2 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from statsmodels) (0.5.4)
# Requirement already satisfied: packaging>=21.3 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from statsmodels) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from pandas>=1.0->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from pandas>=1.0->statsmodels) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from pandas>=1.0->statsmodels) (2023.3)
# Requirement already satisfied: six in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels) (1.15.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from matplotlib) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.26.2)
# Requirement already satisfied: packaging>=20.0 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=8 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from matplotlib) (6.1.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.16.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)

# %%
MaxReps=1000
PREFIX="REACTOME_"#DB to explore for enrichment (see the DB file for other formats "GO_", others...)

# %%
#'''
file="/Users/dolanpt/GitHub_local/doggo/msigdb/msigdb.v2022.1.Mm.symbols.gmt.txt"#CHANGE THIS TO YOUR LOCATION. RUN BLOCK ONCE (to make pickles) THEN COMMENT OUT. 
with open(file,'r') as inf:
    alllines=[line.strip().split("\t") for line in inf]
    DF=pd.concat([pd.DataFrame(zip([l[0]]*len(l[2:]),l[2:]),columns=["term","genes"]) for l in alllines])
pd.to_pickle(DF,"/Users/dolanpt/GitHub_local/doggo/msigdb/msigdb.v2022.1.Mm.symbols.gmt.msigdb.pkl")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 #'''
#       2 file="/Users/dolanpt/GitHub/doggo/msigdb.v7.1.symbols.gmt"#CHANGE THIS TO YOUR LOCATION. RUN BLOCK ONCE (to make pickles) THEN COMMENT OUT.
# ----> 3 with open(file,'r') as inf:
#       4     alllines=[line.strip().split("\t") for line in inf]
#       5     DF=pd.concat([pd.DataFrame(zip([l[0]]*len(l[2:]),l[2:]),columns=["term","genes"]) for l in alllines])
#
# File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/dolanpt/GitHub/doggo/msigdb.v7.1.symbols.gmt'

# %%
MSigDB=pd.read_pickle("/Users/dolanpt/laptop/GitHub/doggo/msigdb.pkl")#CHANGE TO YOUR LOCALE (MATCH ABOVE)

# %%
#This inputData file should be a long table with genes as rows and the data (parameters for filtering and scoring (pval etc.)) for each as columns. 

inputData= "~/Downloads/WT_RD_37.csv"
data=pd.read_table(inputData,delimiter=",")
data
# Out:
#        Unnamed: 0         ens_gene ext_gene          target_id          pval  \
# 0               1  ENSG00000161016     RPL8  ENST00000394920.6  5.285298e-27
# 1               2  ENSG00000142541   RPL13A  ENST00000467825.2  5.820181e-15
# 2               3  ENSG00000184557    SOCS3  ENST00000330871.3  5.183619e-15
# 3               4  ENSG00000138379     MSTN  ENST00000260950.5  2.785983e-13
# 4               5  ENSG00000144713    RPL32  ENST00000457131.1  4.414963e-13
# ...           ...              ...      ...                ...           ...
# 70584       70585              NaN      NaN  ENST00000637549.1  8.482912e-01
# 70585       70586              NaN      NaN  ENST00000637733.1  5.978526e-01
# 70586       70587              NaN      NaN  ENST00000644141.2  9.618411e-01
# 70587       70588              NaN      NaN  ENST00000645777.1  7.704769e-01
# 70588       70589              NaN      NaN  ENST00000677197.1  8.074576e-01
#
#                qval         b      se_b  mean_obs   var_obs  tech_var  \
# 0      3.730839e-22  1.180117  0.109671  8.346138  0.472044  0.009933
# 1      1.369469e-10 -0.556303  0.071250  8.513118  0.106395  0.002855
# 2      1.369469e-10  0.519025  0.066351  6.953304  0.092666  0.001382
# 3      4.916494e-09 -0.367197  0.050271  7.816400  0.046068  0.000508
# 4      6.232956e-09 -0.827729  0.114293  8.127492  0.232328  0.011056
# ...             ...       ...       ...       ...       ...       ...
# 70584  9.999720e-01 -0.134979  0.705589  4.139645  0.181924  0.377386
# 70585  9.999720e-01 -0.091403  0.173279  5.555590  0.017612  0.018043
# 70586  9.999720e-01  0.027082  0.566061  5.089839  0.075538  0.298643
# 70587  9.999720e-01  0.263748  0.904016  2.990525  0.111174  0.044182
# 70588  9.999720e-01 -0.068382  0.280593  4.494900  0.014519  0.019111
#
#        sigma_sq  smooth_sigma_sq  final_sigma_sq
# 0      0.001795         0.002095        0.002095
# 1      0.002001         0.002221        0.002221
# 2      0.002924         0.003021        0.003021
# 3      0.001177         0.002019        0.002019
# 4     -0.005131         0.002007        0.002007
# ...         ...              ...             ...
# 70584 -0.113610         0.120469        0.120469
# 70585  0.004198         0.011983        0.011983
# 70586 -0.185704         0.021782        0.021782
# 70587  0.087797         0.773063        0.773063
# 70588  0.000330         0.059621        0.059621
#
# [70589 rows x 14 columns]

# %%
def computeEnrichment(t,d,P="b",ids="ext_gene",tailed=2):#
    threshold=21
    print(t)
    DBgenes=MSigDB.loc[MSigDB.term==t].genes
    #print(DBgenes)
    totalMean=d[P].values.mean()
    #print(totalMean)
    targets=d.loc[d[ids].isin(DBgenes.values)]
    #print(targets)
    nrowS=targets.shape[0]
    if nrowS>2:#If more that two genes in term set...
        #print(t)
        
        #print(meanSelect)
        nrowT=d.shape[0]
        meanVar=totalMean-targets[P].abs().mean()
        meanSelect=totalMean-targets[P].values.mean()
        positives=0
        denom=0
        if tailed==1:
            if meanSelect < 0:#choose which tail to test...
                while (positives<threshold)&(denom<MaxReps):
                    denom+=1
                    diffSample=totalMean-d[P].iloc[np.random.randint(0,nrowT,nrowS)].mean()
                    positives+=int(diffSample<meanSelect)
            else:
                while (positives<threshold)&(denom<MaxReps):
                    denom+=1                
                    diffSample=totalMean-d[P].iloc[np.random.randint(0,nrowT,nrowS)].mean()
                    positives+=int(diffSample>meanSelect)
        elif tailed==2:
            print("tailed==2")
            while (positives<threshold)&(denom<MaxReps):
                denom+=1
                diffSample=totalMean-d[P].iloc[np.random.randint(0,nrowT,nrowS)].abs().mean()
                positives+=int(diffSample<meanVar)
        else:
            print("Must use 1 or 2 tail.")
        #print(positives/denom)
        #print((meanSelect-totalMean)/totalMean)
    else:
        print("No hits. Skipping Term.")
        return(1.0,1.0,1.0,1.0)
    return([positives/denom, meanSelect, meanVar, nrowS])

# %%
#This is the main block, and needs to be edited based on your data and the parameter (score column you will be sampling in your data.)
def f(term):
    DF=pd.DataFrame([term,computeEnrichment(term,data,"b")],index=["term","pBS"]).transpose()
    return(DF)

#Run across all terms. 
StatResults=pd.DataFrame()
for term in MSigDB.term.unique():
    if term.startswith(PREFIX):
        result=f(term)
        StatResults=pd.concat([StatResults,pd.DataFrame([term,result.pBS[0][0],result.pBS[0][1],result.pBS[0][2],result.pBS[0][3]]).transpose()], ignore_index=True)
StatResults.columns=["term","pBS","meanStat","meanVar","N"]            

pcorr=mult(list(StatResults.pBS))
StatResults['adjPbs']=pcorr[1]
StatResults['sig']=pcorr[0]
StatResults
StatResults.to_csv("WT_RD_37_pBS.csv")
# Out:
# REACTOME_GLYCOGEN_BREAKDOWN_GLYCOGENOLYSIS
# tailed==2
# REACTOME_TRANSLATION
# tailed==2
# REACTOME_PYRIMIDINE_CATABOLISM
# tailed==2
# REACTOME_INHIBITION_OF_THE_PROTEOLYTIC_ACTIVITY_OF_APC_C_REQUIRED_FOR_THE_ONSET_OF_ANAPHASE_BY_MITOTIC_SPINDLE_CHECKPOINT_COMPONENTS
# tailed==2
# REACTOME_PYRUVATE_METABOLISM_AND_CITRIC_ACID_TCA_CYCLE
# tailed==2
# REACTOME_APOPTOTIC_CLEAVAGE_OF_CELLULAR_PROTEINS
# tailed==2
# REACTOME_ACTIVATION_OF_THE_PRE_REPLICATIVE_COMPLEX
# tailed==2
# REACTOME_PROCESSING_OF_INTRONLESS_PRE_MRNAS
# tailed==2
# REACTOME_GAP_JUNCTION_DEGRADATION
# tailed==2
# REACTOME_BASE_EXCISION_REPAIR
# tailed==2
# REACTOME_BILE_ACID_AND_BILE_SALT_METABOLISM
# tailed==2
# REACTOME_SYNTHESIS_OF_BILE_ACIDS_AND_BILE_SALTS_VIA_7ALPHA_HYDROXYCHOLESTEROL
# tailed==2
# REACTOME_RECYCLING_OF_BILE_ACIDS_AND_SALTS
# tailed==2
# REACTOME_SIGNALING_BY_RHO_GTPASES
# tailed==2
# REACTOME_SIGNALING_BY_WNT
# tailed==2
# REACTOME_SYNTHESIS_OF_BILE_ACIDS_AND_BILE_SALTS_VIA_24_HYDROXYCHOLESTEROL
# tailed==2
# REACTOME_SYNTHESIS_OF_BILE_ACIDS_AND_BILE_SALTS
# tailed==2
# REACTOME_ANDROGEN_BIOSYNTHESIS
# tailed==2
# REACTOME_INSULIN_RECEPTOR_RECYCLING
# tailed==2
# REACTOME_NEF_MEDIATED_DOWNREGULATION_OF_MHC_CLASS_I_COMPLEX_CELL_SURFACE_EXPRESSION
# tailed==2
# REACTOME_SIGNALING_BY_SCF_KIT
# tailed==2
# REACTOME_DEVELOPMENTAL_BIOLOGY
# tailed==2
# REACTOME_CROSS_PRESENTATION_OF_SOLUBLE_EXOGENOUS_ANTIGENS_ENDOSOMES
# tailed==2
# REACTOME_SIGNALING_BY_NODAL
# tailed==2
# REACTOME_DAG_AND_IP3_SIGNALING
# tailed==2
# REACTOME_SPRY_REGULATION_OF_FGF_SIGNALING
# tailed==2
# REACTOME_ANTIGEN_PROCESSING_CROSS_PRESENTATION
# tailed==2
# REACTOME_GROWTH_HORMONE_RECEPTOR_SIGNALING
# tailed==2
# REACTOME_CELL_CELL_COMMUNICATION
# tailed==2
# REACTOME_ENDOSOMAL_VACUOLAR_PATHWAY
# tailed==2
# REACTOME_TETRAHYDROBIOPTERIN_BH4_SYNTHESIS_RECYCLING_SALVAGE_AND_REGULATION
# tailed==2
# REACTOME_MEIOSIS
# tailed==2
# REACTOME_G0_AND_EARLY_G1
# tailed==2
# REACTOME_REGULATION_OF_KIT_SIGNALING
# tailed==2
# REACTOME_MEMBRANE_TRAFFICKING
# tailed==2
# REACTOME_NEF_MEDIATES_DOWN_MODULATION_OF_CELL_SURFACE_RECEPTORS_BY_RECRUITING_THEM_TO_CLATHRIN_ADAPTERS
# tailed==2
# REACTOME_IMMUNOREGULATORY_INTERACTIONS_BETWEEN_A_LYMPHOID_AND_A_NON_LYMPHOID_CELL
# tailed==2
# REACTOME_VITAMIN_B5_PANTOTHENATE_METABOLISM
# tailed==2
# REACTOME_METABOLISM_OF_VITAMINS_AND_COFACTORS
# tailed==2
# REACTOME_TRANS_GOLGI_NETWORK_VESICLE_BUDDING
# tailed==2
# REACTOME_RESOLUTION_OF_AP_SITES_VIA_THE_MULTIPLE_NUCLEOTIDE_PATCH_REPLACEMENT_PATHWAY
# tailed==2
# REACTOME_GAMMA_CARBOXYLATION_TRANSPORT_AND_AMINO_TERMINAL_CLEAVAGE_OF_PROTEINS
# tailed==2
# REACTOME_CELL_CYCLE
# tailed==2
# REACTOME_SIGNALING_BY_ERBB4
# tailed==2
# REACTOME_ORC1_REMOVAL_FROM_CHROMATIN
# tailed==2
# REACTOME_O_LINKED_GLYCOSYLATION_OF_MUCINS
# tailed==2
# REACTOME_SULFUR_AMINO_ACID_METABOLISM
# tailed==2
# REACTOME_DOWNREGULATION_OF_ERBB2_ERBB3_SIGNALING
# tailed==2
# REACTOME_ANTIVIRAL_MECHANISM_BY_IFN_STIMULATED_GENES
# tailed==2
# REACTOME_PROLACTIN_RECEPTOR_SIGNALING
# tailed==2
# REACTOME_SIGNALING_BY_ERBB2
# tailed==2
# REACTOME_SPHINGOLIPID_DE_NOVO_BIOSYNTHESIS
# tailed==2
# REACTOME_TERMINATION_OF_O_GLYCAN_BIOSYNTHESIS
# tailed==2
# REACTOME_DEFENSINS
# tailed==2
# REACTOME_CONSTITUTIVE_SIGNALING_BY_LIGAND_RESPONSIVE_EGFR_CANCER_VARIANTS
# tailed==2
# REACTOME_GRB2_EVENTS_IN_ERBB2_SIGNALING
# tailed==2
# REACTOME_SIGNALING_BY_EGFR_IN_CANCER
# tailed==2
# REACTOME_BETA_DEFENSINS
# tailed==2
# REACTOME_SRP_DEPENDENT_COTRANSLATIONAL_PROTEIN_TARGETING_TO_MEMBRANE
# tailed==2
# REACTOME_PI3K_EVENTS_IN_ERBB4_SIGNALING
# tailed==2
# REACTOME_SHC1_EVENTS_IN_ERBB4_SIGNALING
# tailed==2
# REACTOME_PI3K_EVENTS_IN_ERBB2_SIGNALING
# tailed==2
# REACTOME_NUCLEAR_SIGNALING_BY_ERBB4
# tailed==2
# REACTOME_GLYCOSPHINGOLIPID_METABOLISM
# tailed==2
# REACTOME_DEGRADATION_OF_THE_EXTRACELLULAR_MATRIX
# tailed==2
# REACTOME_MITOCHONDRIAL_PROTEIN_IMPORT
# tailed==2
# REACTOME_SIGNALING_BY_HIPPO
# tailed==2
# REACTOME_ACTIVATED_NOTCH1_TRANSMITS_SIGNAL_TO_THE_NUCLEUS
# tailed==2
# REACTOME_TRAFFICKING_AND_PROCESSING_OF_ENDOSOMAL_TLR
# tailed==2
# REACTOME_SIGNALING_BY_NOTCH4
# tailed==2
# REACTOME_DOWNSTREAM_SIGNALING_EVENTS_OF_B_CELL_RECEPTOR_BCR
# tailed==2
# REACTOME_YAP1_AND_WWTR1_TAZ_STIMULATED_GENE_EXPRESSION
# tailed==2
# REACTOME_SIGNALING_BY_NOTCH2
# tailed==2
# REACTOME_PRE_NOTCH_EXPRESSION_AND_PROCESSING
# tailed==2
# REACTOME_SIGNALING_BY_THE_B_CELL_RECEPTOR_BCR
# tailed==2
# REACTOME_EXTRACELLULAR_MATRIX_ORGANIZATION
# tailed==2
# REACTOME_NOTCH1_INTRACELLULAR_DOMAIN_REGULATES_TRANSCRIPTION
# tailed==2
# REACTOME_PRE_NOTCH_PROCESSING_IN_GOLGI
# tailed==2
# REACTOME_SIGNALING_BY_NOTCH1
# tailed==2
# REACTOME_SIGNALING_BY_NOTCH3
# tailed==2
# REACTOME_TRIGLYCERIDE_BIOSYNTHESIS
# tailed==2
# REACTOME_INSULIN_RECEPTOR_SIGNALLING_CASCADE
# tailed==2
# REACTOME_ARMS_MEDIATED_ACTIVATION
# tailed==2
# REACTOME_PROLONGED_ERK_ACTIVATION_EVENTS
# tailed==2
# REACTOME_SIGNALLING_TO_RAS
# tailed==2
# REACTOME_SIGNALING_BY_BMP
# tailed==2
# REACTOME_CELL_SURFACE_INTERACTIONS_AT_THE_VASCULAR_WALL
# tailed==2
# REACTOME_SIGNALLING_TO_ERKS
# tailed==2
# REACTOME_P38MAPK_EVENTS
# tailed==2
# REACTOME_ACYL_CHAIN_REMODELLING_OF_PI
# tailed==2
# REACTOME_TGF_BETA_RECEPTOR_SIGNALING_IN_EMT_EPITHELIAL_TO_MESENCHYMAL_TRANSITION
# tailed==2
# REACTOME_DOWNREGULATION_OF_TGF_BETA_RECEPTOR_SIGNALING
# tailed==2
# REACTOME_COLLAGEN_FORMATION
# tailed==2
# REACTOME_SMAD2_SMAD3_SMAD4_HETEROTRIMER_REGULATES_TRANSCRIPTION
# tailed==2
# REACTOME_SIGNALING_BY_FGFR_IN_DISEASE
# tailed==2
# REACTOME_HS_GAG_DEGRADATION
# tailed==2
# REACTOME_SYNTHESIS_OF_PIPS_AT_THE_EARLY_ENDOSOME_MEMBRANE
# tailed==2
# REACTOME_SIGNALLING_TO_P38_VIA_RIT_AND_RIN
# tailed==2
# REACTOME_ACYL_CHAIN_REMODELLING_OF_PC
# tailed==2
# REACTOME_SYNTHESIS_OF_PIPS_AT_THE_GOLGI_MEMBRANE
# tailed==2
# REACTOME_TGF_BETA_RECEPTOR_SIGNALING_ACTIVATES_SMADS
# tailed==2
# REACTOME_PHOSPHOLIPID_METABOLISM
# tailed==2
# REACTOME_CS_DS_DEGRADATION
# tailed==2
# REACTOME_SYNTHESIS_OF_PA
# tailed==2
# REACTOME_SYNTHESIS_OF_PIPS_AT_THE_LATE_ENDOSOME_MEMBRANE
# tailed==2
# REACTOME_SYNTHESIS_OF_PE
# tailed==2
# REACTOME_GASTRIN_CREB_SIGNALLING_PATHWAY_VIA_PKC_AND_MAPK
# tailed==2
# REACTOME_CHONDROITIN_SULFATE_BIOSYNTHESIS
# tailed==2
# REACTOME_HYALURONAN_UPTAKE_AND_DEGRADATION
# tailed==2
# REACTOME_SYNTHESIS_OF_PIPS_AT_THE_PLASMA_MEMBRANE
# tailed==2
# REACTOME_THE_ACTIVATION_OF_ARYLSULFATASES
# tailed==2
# REACTOME_TRANSCRIPTIONAL_ACTIVITY_OF_SMAD2_SMAD3_SMAD4_HETEROTRIMER
# tailed==2
# REACTOME_HYALURONAN_METABOLISM
# tailed==2
# REACTOME_DOWNREGULATION_OF_SMAD2_3_SMAD4_TRANSCRIPTIONAL_ACTIVITY
# tailed==2
# REACTOME_KERATAN_SULFATE_BIOSYNTHESIS
# tailed==2
# REACTOME_REVERSIBLE_HYDRATION_OF_CARBON_DIOXIDE
# tailed==2
# REACTOME_PI_METABOLISM
# tailed==2
# REACTOME_ABACAVIR_TRANSPORT_AND_METABOLISM
# tailed==2
# REACTOME_CHONDROITIN_SULFATE_DERMATAN_SULFATE_METABOLISM
# tailed==2
# REACTOME_SYNTHESIS_OF_PC
# tailed==2
# REACTOME_HS_GAG_BIOSYNTHESIS
# tailed==2
# REACTOME_KERATAN_SULFATE_KERATIN_METABOLISM
# tailed==2
# REACTOME_APOPTOSIS_INDUCED_DNA_FRAGMENTATION
# tailed==2
# REACTOME_KERATAN_SULFATE_DEGRADATION
# tailed==2
# REACTOME_HEPARAN_SULFATE_HEPARIN_HS_GAG_METABOLISM
# tailed==2
# REACTOME_GLYCOSAMINOGLYCAN_METABOLISM
# tailed==2
# REACTOME_ACYL_CHAIN_REMODELLING_OF_PG
# tailed==2
# REACTOME_ACYL_CHAIN_REMODELLING_OF_PE
# tailed==2
# REACTOME_ACYL_CHAIN_REMODELLING_OF_PS
# tailed==2
# REACTOME_MHC_CLASS_II_ANTIGEN_PRESENTATION
# tailed==2
# REACTOME_GLYCEROPHOSPHOLIPID_BIOSYNTHESIS
# tailed==2
# REACTOME_A_TETRASACCHARIDE_LINKER_SEQUENCE_IS_REQUIRED_FOR_GAG_SYNTHESIS
# tailed==2
# REACTOME_PLATELET_ADHESION_TO_EXPOSED_COLLAGEN
# tailed==2
# REACTOME_VEGF_LIGAND_RECEPTOR_INTERACTIONS
# tailed==2
# REACTOME_MICRORNA_MIRNA_BIOGENESIS
# tailed==2
# REACTOME_NUCLEAR_EVENTS_KINASE_AND_TRANSCRIPTION_FACTOR_ACTIVATION
# tailed==2
# REACTOME_RETROGRADE_NEUROTROPHIN_SIGNALLING
# tailed==2
# REACTOME_ERKS_ARE_INACTIVATED
# tailed==2
# REACTOME_NEGATIVE_REGULATION_OF_THE_PI3K_AKT_NETWORK
# tailed==2
# REACTOME_PI3K_AKT_ACTIVATION
# tailed==2
# REACTOME_EGFR_DOWNREGULATION
# tailed==2
# REACTOME_PROCESSING_OF_CAPPED_INTRON_CONTAINING_PRE_MRNA
# tailed==2
# REACTOME_PECAM1_INTERACTIONS
# tailed==2
# REACTOME_TCR_SIGNALING
# tailed==2
# REACTOME_REGULATION_OF_PYRUVATE_DEHYDROGENASE_PDH_COMPLEX
# tailed==2
# REACTOME_BASIGIN_INTERACTIONS
# tailed==2
# REACTOME_AKT_PHOSPHORYLATES_TARGETS_IN_THE_CYTOSOL
# tailed==2
# REACTOME_GAB1_SIGNALOSOME
# tailed==2
# REACTOME_SHC1_EVENTS_IN_EGFR_SIGNALING
# tailed==2
# REACTOME_ACTIVATION_OF_THE_MRNA_UPON_BINDING_OF_THE_CAP_BINDING_COMPLEX_AND_EIFS_AND_SUBSEQUENT_BINDING_TO_43S
# tailed==2
# REACTOME_GLUTAMATE_NEUROTRANSMITTER_RELEASE_CYCLE
# tailed==2
# REACTOME_ERK_MAPK_TARGETS
# tailed==2
# REACTOME_TIE2_SIGNALING
# tailed==2
# REACTOME_GENERATION_OF_SECOND_MESSENGER_MOLECULES
# tailed==2
# REACTOME_RESPONSE_TO_ELEVATED_PLATELET_CYTOSOLIC_CA2
# tailed==2
# REACTOME_TRANSPORT_OF_MATURE_TRANSCRIPT_TO_CYTOPLASM
# tailed==2
# REACTOME_METABOLISM_OF_AMINO_ACIDS_AND_DERIVATIVES
# tailed==2
# REACTOME_FATTY_ACYL_COA_BIOSYNTHESIS
# tailed==2
# REACTOME_E2F_ENABLED_INHIBITION_OF_PRE_REPLICATION_COMPLEX_FORMATION
# tailed==2
# REACTOME_P75NTR_RECRUITS_SIGNALLING_COMPLEXES
# tailed==2
# REACTOME_BIOLOGICAL_OXIDATIONS
# tailed==2
# REACTOME_REGULATED_PROTEOLYSIS_OF_P75NTR
# tailed==2
# REACTOME_TRANSMISSION_ACROSS_CHEMICAL_SYNAPSES
# tailed==2
# REACTOME_CASPASE_MEDIATED_CLEAVAGE_OF_CYTOSKELETAL_PROTEINS
# tailed==2
# REACTOME_XENOBIOTICS
# tailed==2
# REACTOME_INTEGRIN_CELL_SURFACE_INTERACTIONS
# tailed==2
# REACTOME_CYTOCHROME_P450_ARRANGED_BY_SUBSTRATE_TYPE
# tailed==2
# REACTOME_APOPTOTIC_CLEAVAGE_OF_CELL_ADHESION_PROTEINS
# tailed==2
# REACTOME_NRAGE_SIGNALS_DEATH_THROUGH_JNK
# tailed==2
# REACTOME_SLBP_DEPENDENT_PROCESSING_OF_REPLICATION_DEPENDENT_HISTONE_PRE_MRNAS
# tailed==2
# REACTOME_NRIF_SIGNALS_CELL_DEATH_FROM_THE_NUCLEUS
# tailed==2
# REACTOME_RNA_POLYMERASE_II_TRANSCRIPTION
# tailed==2
# REACTOME_NEURONAL_SYSTEM
# tailed==2
# REACTOME_REGULATION_OF_BETA_CELL_DEVELOPMENT
# tailed==2
# REACTOME_CELL_DEATH_SIGNALLING_VIA_NRAGE_NRIF_AND_NADE
# tailed==2
# REACTOME_NEUROTRANSMITTER_RELEASE_CYCLE
# tailed==2
# REACTOME_P75_NTR_RECEPTOR_MEDIATED_SIGNALLING
# tailed==2
# REACTOME_AMINO_ACID_TRANSPORT_ACROSS_THE_PLASMA_MEMBRANE
# tailed==2
# REACTOME_ENDOGENOUS_STEROLS
# tailed==2
# REACTOME_REGULATION_OF_GENE_EXPRESSION_IN_BETA_CELLS
# tailed==2
# REACTOME_GLYCOLYSIS
# tailed==2
# REACTOME_PROCESSIVE_SYNTHESIS_ON_THE_LAGGING_STRAND
# tailed==2
# REACTOME_MRNA_CAPPING
# tailed==2
# REACTOME_MITOCHONDRIAL_FATTY_ACID_BETA_OXIDATION
# tailed==2
# REACTOME_SIGNALING_BY_GPCR
# tailed==2
# REACTOME_PEPTIDE_LIGAND_BINDING_RECEPTORS
# tailed==2
# REACTOME_METABOLISM_OF_POLYAMINES
# tailed==2
# REACTOME_NOTCH_HLH_TRANSCRIPTION_PATHWAY
# tailed==2
# REACTOME_INTEGRATION_OF_ENERGY_METABOLISM
# tailed==2
# REACTOME_CELL_CYCLE_MITOTIC
# tailed==2
# REACTOME_GLUCONEOGENESIS
# tailed==2
# REACTOME_DOPAMINE_NEUROTRANSMITTER_RELEASE_CYCLE
# tailed==2
# REACTOME_OPIOID_SIGNALLING
# tailed==2
# REACTOME_RECRUITMENT_OF_MITOTIC_CENTROSOME_PROTEINS_AND_COMPLEXES
# tailed==2
# REACTOME_MITOCHONDRIAL_TRNA_AMINOACYLATION
# tailed==2
# REACTOME_CYTOSOLIC_TRNA_AMINOACYLATION
# tailed==2
# REACTOME_CA_DEPENDENT_EVENTS
# tailed==2
# REACTOME_ACETYLCHOLINE_NEUROTRANSMITTER_RELEASE_CYCLE
# tailed==2
# REACTOME_ADENYLATE_CYCLASE_ACTIVATING_PATHWAY
# tailed==2
# REACTOME_ADENYLATE_CYCLASE_INHIBITORY_PATHWAY
# tailed==2
# REACTOME_DARPP_32_EVENTS
# tailed==2
# REACTOME_CHEMOKINE_RECEPTORS_BIND_CHEMOKINES
# tailed==2
# REACTOME_CELL_CYCLE_CHECKPOINTS
# tailed==2
# REACTOME_P130CAS_LINKAGE_TO_MAPK_SIGNALING_FOR_INTEGRINS
# tailed==2
# REACTOME_NOREPINEPHRINE_NEUROTRANSMITTER_RELEASE_CYCLE
# tailed==2
# REACTOME_PEPTIDE_HORMONE_BIOSYNTHESIS
# tailed==2
# REACTOME_G_PROTEIN_ACTIVATION
# tailed==2
# REACTOME_ACETYLCHOLINE_BINDING_AND_DOWNSTREAM_EVENTS
# tailed==2
# REACTOME_ABC_FAMILY_PROTEINS_MEDIATED_TRANSPORT
# tailed==2
# REACTOME_TRNA_AMINOACYLATION
# tailed==2
# REACTOME_OLFACTORY_SIGNALING_PATHWAY
# tailed==2
# REACTOME_PKA_MEDIATED_PHOSPHORYLATION_OF_CREB
# tailed==2
# REACTOME_RECRUITMENT_OF_NUMA_TO_MITOTIC_CENTROSOMES
# tailed==2
# REACTOME_NUCLEAR_RECEPTOR_TRANSCRIPTION_PATHWAY
# tailed==2
# REACTOME_GLUCAGON_SIGNALING_IN_METABOLIC_REGULATION
# tailed==2
# REACTOME_SIGNALING_BY_PDGF
# tailed==2
# REACTOME_ASSOCIATION_OF_TRIC_CCT_WITH_TARGET_PROTEINS_DURING_BIOSYNTHESIS
# tailed==2
# REACTOME_HORMONE_LIGAND_BINDING_RECEPTORS
# tailed==2
# REACTOME_GPVI_MEDIATED_ACTIVATION_CASCADE
# tailed==2
# REACTOME_PROTEIN_FOLDING
# tailed==2
# REACTOME_FORMATION_OF_TUBULIN_FOLDING_INTERMEDIATES_BY_CCT_TRIC
# tailed==2
# REACTOME_PEROXISOMAL_LIPID_METABOLISM
# tailed==2
# REACTOME_POST_CHAPERONIN_TUBULIN_FOLDING_PATHWAY
# tailed==2
# REACTOME_STRIATED_MUSCLE_CONTRACTION
# tailed==2
# REACTOME_METABOLISM_OF_NUCLEOTIDES
# tailed==2
# REACTOME_AMINE_LIGAND_BINDING_RECEPTORS
# tailed==2
# REACTOME_DOWNSTREAM_SIGNAL_TRANSDUCTION
# tailed==2
# REACTOME_MUSCLE_CONTRACTION
# tailed==2
# REACTOME_SEROTONIN_RECEPTORS
# No hits. Skipping Term.
# REACTOME_CDC6_ASSOCIATION_WITH_THE_ORC_ORIGIN_COMPLEX
# tailed==2
# REACTOME_MRNA_SPLICING
# tailed==2
# REACTOME_MRNA_SPLICING_MINOR_PATHWAY
# tailed==2
# REACTOME_PROCESSING_OF_CAPPED_INTRONLESS_PRE_MRNA
# tailed==2
# REACTOME_PURINE_RIBONUCLEOSIDE_MONOPHOSPHATE_BIOSYNTHESIS
# tailed==2
# REACTOME_CITRIC_ACID_CYCLE_TCA_CYCLE
# tailed==2
# REACTOME_POLYMERASE_SWITCHING
# tailed==2
# REACTOME_NUCLEOTIDE_EXCISION_REPAIR
# tailed==2
# REACTOME_G_ALPHA_Q_SIGNALLING_EVENTS
# tailed==2
# REACTOME_P2Y_RECEPTORS
# tailed==2
# REACTOME_TRAFFICKING_OF_AMPA_RECEPTORS
# tailed==2
# REACTOME_NCAM1_INTERACTIONS
# tailed==2
# REACTOME_CLASS_C_3_METABOTROPIC_GLUTAMATE_PHEROMONE_RECEPTORS
# tailed==2
# REACTOME_REGULATION_OF_INSULIN_SECRETION
# tailed==2
# REACTOME_NCAM_SIGNALING_FOR_NEURITE_OUT_GROWTH
# tailed==2
# REACTOME_NUCLEOTIDE_LIKE_PURINERGIC_RECEPTORS
# tailed==2
# REACTOME_EICOSANOID_LIGAND_BINDING_RECEPTORS
# tailed==2
# REACTOME_CLASS_B_2_SECRETIN_FAMILY_RECEPTORS
# tailed==2
# REACTOME_GLUCAGON_TYPE_LIGAND_RECEPTORS
# tailed==2
# REACTOME_FANCONI_ANEMIA_PATHWAY
# tailed==2
# REACTOME_TRAFFICKING_OF_GLUR2_CONTAINING_AMPA_RECEPTORS
# tailed==2
# REACTOME_PROSTANOID_LIGAND_RECEPTORS
# tailed==2
# REACTOME_OPSINS
# tailed==2
# REACTOME_FORMATION_OF_RNA_POL_II_ELONGATION_COMPLEX
# tailed==2
# REACTOME_SLC_MEDIATED_TRANSMEMBRANE_TRANSPORT
# tailed==2
# REACTOME_CD28_CO_STIMULATION
# tailed==2
# REACTOME_SYNTHESIS_SECRETION_AND_DEACYLATION_OF_GHRELIN
# tailed==2
# REACTOME_ADHERENS_JUNCTIONS_INTERACTIONS
# tailed==2
# REACTOME_CRMPS_IN_SEMA3A_SIGNALING
# tailed==2
# REACTOME_OTHER_SEMAPHORIN_INTERACTIONS
# tailed==2
# REACTOME_PURINE_SALVAGE
# tailed==2
# REACTOME_G_ALPHA_I_SIGNALLING_EVENTS
# tailed==2
# REACTOME_SEMA3A_PAK_DEPENDENT_AXON_REPULSION
# tailed==2
# REACTOME_CD28_DEPENDENT_VAV1_PATHWAY
# tailed==2
# REACTOME_SEMA4D_IN_SEMAPHORIN_SIGNALING
# tailed==2
# REACTOME_SEMAPHORIN_INTERACTIONS
# tailed==2
# REACTOME_SEMA4D_INDUCED_CELL_MIGRATION_AND_GROWTH_CONE_COLLAPSE
# tailed==2
# REACTOME_SEMA3A_PLEXIN_REPULSION_SIGNALING_BY_INHIBITING_INTEGRIN_ADHESION
# tailed==2
# REACTOME_LYSOSOME_VESICLE_BIOGENESIS
# tailed==2
# REACTOME_G_BETA_GAMMA_SIGNALLING_THROUGH_PI3KGAMMA
# tailed==2
# REACTOME_SPHINGOLIPID_METABOLISM
# tailed==2
# REACTOME_G_ALPHA_S_SIGNALLING_EVENTS
# tailed==2
# REACTOME_CELL_CELL_JUNCTION_ORGANIZATION
# tailed==2
# REACTOME_G_ALPHA_Z_SIGNALLING_EVENTS
# tailed==2
# REACTOME_COSTIMULATION_BY_THE_CD28_FAMILY
# tailed==2
# REACTOME_CD28_DEPENDENT_PI3K_AKT_SIGNALING
# tailed==2
# REACTOME_TIGHT_JUNCTION_INTERACTIONS
# tailed==2
# REACTOME_G_PROTEIN_BETA_GAMMA_SIGNALLING
# tailed==2
# REACTOME_TRANSPORT_OF_INORGANIC_CATIONS_ANIONS_AND_AMINO_ACIDS_OLIGOPEPTIDES
# tailed==2
# REACTOME_GOLGI_ASSOCIATED_VESICLE_BIOGENESIS
# tailed==2
# REACTOME_CTLA4_INHIBITORY_SIGNALING
# tailed==2
# REACTOME_BRANCHED_CHAIN_AMINO_ACID_CATABOLISM
# tailed==2
# REACTOME_FORMATION_OF_FIBRIN_CLOT_CLOTTING_CASCADE
# tailed==2
# REACTOME_DEADENYLATION_OF_MRNA
# tailed==2
# REACTOME_MRNA_DECAY_BY_5_TO_3_EXORIBONUCLEASE
# tailed==2
# REACTOME_SIGNAL_AMPLIFICATION
# tailed==2
# REACTOME_ZINC_TRANSPORTERS
# tailed==2
# REACTOME_METAL_ION_SLC_TRANSPORTERS
# tailed==2
# REACTOME_SMOOTH_MUSCLE_CONTRACTION
# tailed==2
# REACTOME_MRNA_DECAY_BY_3_TO_5_EXORIBONUCLEASE
# tailed==2
# REACTOME_DEADENYLATION_DEPENDENT_MRNA_DECAY
# tailed==2
# REACTOME_THROMBOXANE_SIGNALLING_THROUGH_TP_RECEPTOR
# tailed==2
# REACTOME_CELL_EXTRACELLULAR_MATRIX_INTERACTIONS
# tailed==2
# REACTOME_CELL_JUNCTION_ORGANIZATION
# tailed==2
# REACTOME_PYRUVATE_METABOLISM
# tailed==2
# REACTOME_PURINE_CATABOLISM
# tailed==2
# REACTOME_METABOLISM_OF_RNA
# tailed==2
# REACTOME_MITOTIC_G1_PHASE_AND_G1_S_TRANSITION
# tailed==2
# REACTOME_TAK1_ACTIVATES_NFKB_BY_PHOSPHORYLATION_AND_ACTIVATION_OF_IKKS_COMPLEX
# tailed==2
# REACTOME_MYOGENESIS
# tailed==2
# REACTOME_ACTIVATION_OF_KAINATE_RECEPTORS_UPON_GLUTAMATE_BINDING
# tailed==2
# REACTOME_IONOTROPIC_ACTIVITY_OF_KAINATE_RECEPTORS
# tailed==2
# REACTOME_MAPK_TARGETS_NUCLEAR_EVENTS_MEDIATED_BY_MAP_KINASES
# tailed==2
# REACTOME_GPCR_LIGAND_BINDING
# tailed==2
# REACTOME_JNK_C_JUN_KINASES_PHOSPHORYLATION_AND_ACTIVATION_MEDIATED_BY_ACTIVATED_HUMAN_TAK1
# tailed==2
# REACTOME_THROMBIN_SIGNALLING_THROUGH_PROTEINASE_ACTIVATED_RECEPTORS_PARS
# tailed==2
# REACTOME_ENERGY_DEPENDENT_REGULATION_OF_MTOR_BY_LKB1_AMPK
# tailed==2
# REACTOME_MITOTIC_G2_G2_M_PHASES
# tailed==2
# REACTOME_ACTIVATED_TAK1_MEDIATES_P38_MAPK_ACTIVATION
# tailed==2
# REACTOME_DNA_REPAIR
# tailed==2
# REACTOME_EFFECTS_OF_PIP2_HYDROLYSIS
# tailed==2
# REACTOME_POST_TRANSLATIONAL_PROTEIN_MODIFICATION
# tailed==2
# REACTOME_CHROMOSOME_MAINTENANCE
# tailed==2
# REACTOME_L1CAM_INTERACTIONS
# tailed==2
# REACTOME_INTERACTION_BETWEEN_L1_AND_ANKYRINS
# tailed==2
# REACTOME_SIGNAL_TRANSDUCTION_BY_L1
# tailed==2
# REACTOME_TRANSPORT_OF_VITAMINS_NUCLEOSIDES_AND_RELATED_MOLECULES
# tailed==2
# REACTOME_HIGHLY_CALCIUM_PERMEABLE_POSTSYNAPTIC_NICOTINIC_ACETYLCHOLINE_RECEPTORS
# tailed==2
# REACTOME_ORGANIC_CATION_ANION_ZWITTERION_TRANSPORT
# tailed==2
# REACTOME_DCC_MEDIATED_ATTRACTIVE_SIGNALING
# tailed==2
# REACTOME_RECYCLING_PATHWAY_OF_L1
# tailed==2
# REACTOME_SYNTHESIS_OF_SUBSTRATES_IN_N_GLYCAN_BIOSYTHESIS
# tailed==2
# REACTOME_RESPIRATORY_ELECTRON_TRANSPORT
# tailed==2
# REACTOME_ASPARAGINE_N_LINKED_GLYCOSYLATION
# tailed==2
# REACTOME_ASSEMBLY_OF_THE_PRE_REPLICATIVE_COMPLEX
# tailed==2
# REACTOME_BIOSYNTHESIS_OF_THE_N_GLYCAN_PRECURSOR_DOLICHOL_LIPID_LINKED_OLIGOSACCHARIDE_LLO_AND_TRANSFER_TO_A_NASCENT_PROTEIN
# tailed==2
# REACTOME_CGMP_EFFECTS
# tailed==2
# REACTOME_REGULATION_OF_SIGNALING_BY_CBL
# tailed==2
# REACTOME_CALNEXIN_CALRETICULIN_CYCLE
# tailed==2
# REACTOME_PASSIVE_TRANSPORT_BY_AQUAPORINS
# tailed==2
# REACTOME_NITRIC_OXIDE_STIMULATES_GUANYLATE_CYCLASE
# tailed==2
# REACTOME_PLATELET_HOMEOSTASIS
# tailed==2
# REACTOME_N_GLYCAN_TRIMMING_IN_THE_ER_AND_CALNEXIN_CALRETICULIN_CYCLE
# tailed==2
# REACTOME_PLATELET_SENSITIZATION_BY_LDL
# tailed==2
# REACTOME_AQUAPORIN_MEDIATED_TRANSPORT
# tailed==2
# REACTOME_RAP1_SIGNALLING
# tailed==2
# REACTOME_PLATELET_CALCIUM_HOMEOSTASIS
# tailed==2
# REACTOME_PROSTACYCLIN_SIGNALLING_THROUGH_PROSTACYCLIN_RECEPTOR
# tailed==2
# REACTOME_GABA_SYNTHESIS_RELEASE_REUPTAKE_AND_DEGRADATION
# tailed==2
# REACTOME_INCRETIN_SYNTHESIS_SECRETION_AND_INACTIVATION
# tailed==2
# REACTOME_TRANSPORT_OF_ORGANIC_ANIONS
# tailed==2
# REACTOME_SYNTHESIS_SECRETION_AND_INACTIVATION_OF_GLUCAGON_LIKE_PEPTIDE_1_GLP_1
# tailed==2
# REACTOME_IRAK1_RECRUITS_IKK_COMPLEX
# tailed==2
# REACTOME_TRAF6_MEDIATED_IRF7_ACTIVATION
# tailed==2
# REACTOME_CIRCADIAN_CLOCK
# tailed==2
# REACTOME_FACTORS_INVOLVED_IN_MEGAKARYOCYTE_DEVELOPMENT_AND_PLATELET_PRODUCTION
# tailed==2
# REACTOME_REGULATION_OF_IFNG_SIGNALING
# tailed==2
# REACTOME_REGULATION_OF_MRNA_STABILITY_BY_PROTEINS_THAT_BIND_AU_RICH_ELEMENTS
# tailed==2
# REACTOME_TRAF3_DEPENDENT_IRF_ACTIVATION_PATHWAY
# tailed==2
# REACTOME_GABA_B_RECEPTOR_ACTIVATION
# tailed==2
# REACTOME_TRANSPORT_TO_THE_GOLGI_AND_SUBSEQUENT_MODIFICATION
# tailed==2
# REACTOME_IRON_UPTAKE_AND_TRANSPORT
# tailed==2
# REACTOME_INTERFERON_GAMMA_SIGNALING
# tailed==2
# REACTOME_N_GLYCAN_ANTENNAE_ELONGATION
# tailed==2
# REACTOME_TRAF6_MEDIATED_IRF7_ACTIVATION_IN_TLR7_8_OR_9_SIGNALING
# tailed==2
# REACTOME_ACTIVATION_OF_IRF3_IRF7_MEDIATED_BY_TBK1_IKK_EPSILON
# tailed==2
# REACTOME_ION_TRANSPORT_BY_P_TYPE_ATPASES
# tailed==2
# REACTOME_INTERFERON_ALPHA_BETA_SIGNALING
# tailed==2
# REACTOME_ADVANCED_GLYCOSYLATION_ENDPRODUCT_RECEPTOR_SIGNALING
# tailed==2
# REACTOME_GABA_RECEPTOR_ACTIVATION
# tailed==2
# REACTOME_KINESINS
# tailed==2
# REACTOME_N_GLYCAN_ANTENNAE_ELONGATION_IN_THE_MEDIAL_TRANS_GOLGI
# tailed==2
# REACTOME_REGULATION_OF_IFNA_SIGNALING
# tailed==2
# REACTOME_INTERFERON_SIGNALING
# tailed==2
# REACTOME_TRANSFERRIN_ENDOCYTOSIS_AND_RECYCLING
# tailed==2
# REACTOME_DSCAM_INTERACTIONS
# tailed==2
# REACTOME_ION_CHANNEL_TRANSPORT
# tailed==2
# REACTOME_IKK_COMPLEX_RECRUITMENT_MEDIATED_BY_RIP1
# tailed==2
# REACTOME_FORMATION_OF_INCISION_COMPLEX_IN_GG_NER
# tailed==2
# REACTOME_TRANSCRIPTIONAL_REGULATION_OF_WHITE_ADIPOCYTE_DIFFERENTIATION
# tailed==2
# REACTOME_ENDOSOMAL_SORTING_COMPLEX_REQUIRED_FOR_TRANSPORT_ESCRT
# tailed==2
# REACTOME_MEIOTIC_RECOMBINATION
# tailed==2
# REACTOME_PLATELET_AGGREGATION_PLUG_FORMATION
# tailed==2
# REACTOME_SIGNALING_BY_NOTCH
# tailed==2
# REACTOME_LAGGING_STRAND_SYNTHESIS
# tailed==2
# REACTOME_INHIBITION_OF_REPLICATION_INITIATION_OF_DAMAGED_DNA_BY_RB1_E2F1
# tailed==2
# REACTOME_ETHANOL_OXIDATION
# tailed==2
# REACTOME_SYNTHESIS_OF_VERY_LONG_CHAIN_FATTY_ACYL_COAS
# tailed==2
# REACTOME_DNA_REPLICATION
# tailed==2
# REACTOME_E2F_MEDIATED_REGULATION_OF_DNA_REPLICATION
# tailed==2
# REACTOME_METABOLISM_OF_CARBOHYDRATES
# tailed==2
# REACTOME_SIGNALING_BY_INSULIN_RECEPTOR
# tailed==2
# REACTOME_SIGNAL_ATTENUATION
# tailed==2
# REACTOME_SOS_MEDIATED_SIGNALLING
# tailed==2
# REACTOME_HEMOSTASIS
# tailed==2
# REACTOME_HIV_INFECTION
# tailed==2
# REACTOME_HIV_LIFE_CYCLE
# tailed==2
# REACTOME_EARLY_PHASE_OF_HIV_LIFE_CYCLE
# tailed==2
# REACTOME_HOST_INTERACTIONS_OF_HIV_FACTORS
# tailed==2
# REACTOME_RESPIRATORY_ELECTRON_TRANSPORT_ATP_SYNTHESIS_BY_CHEMIOSMOTIC_COUPLING_AND_HEAT_PRODUCTION_BY_UNCOUPLING_PROTEINS
# tailed==2
# REACTOME_VIRAL_MESSENGER_RNA_SYNTHESIS
# tailed==2
# REACTOME_INTERACTIONS_OF_VPR_WITH_HOST_CELLULAR_PROTEINS
# tailed==2
# REACTOME_FORMATION_OF_ATP_BY_CHEMIOSMOTIC_COUPLING
# tailed==2
# REACTOME_APC_C_CDH1_MEDIATED_DEGRADATION_OF_CDC20_AND_OTHER_APC_C_CDH1_TARGETED_PROTEINS_IN_LATE_MITOSIS_EARLY_G1
# tailed==2
# REACTOME_ACTIVATION_OF_ATR_IN_RESPONSE_TO_REPLICATION_STRESS
# tailed==2
# REACTOME_UNWINDING_OF_DNA
# tailed==2
# REACTOME_GLUCURONIDATION
# tailed==2
# REACTOME_INNATE_IMMUNE_SYSTEM
# tailed==2
# REACTOME_MITOTIC_PROMETAPHASE
# tailed==2
# REACTOME_APC_C_CDC20_MEDIATED_DEGRADATION_OF_CYCLIN_B
# tailed==2
# REACTOME_G1_S_SPECIFIC_TRANSCRIPTION
# tailed==2
# REACTOME_SIGNALING_BY_TGF_BETA_RECEPTOR_COMPLEX
# tailed==2
# REACTOME_CONVERSION_FROM_APC_C_CDC20_TO_APC_C_CDH1_IN_LATE_ANAPHASE
# tailed==2
# REACTOME_PHOSPHORYLATION_OF_THE_APC_C
# tailed==2
# REACTOME_CYTOSOLIC_SULFONATION_OF_SMALL_MOLECULES
# tailed==2
# REACTOME_INTEGRATION_OF_PROVIRUS
# tailed==2
# REACTOME_GLUTATHIONE_CONJUGATION
# tailed==2
# REACTOME_COMPLEMENT_CASCADE
# tailed==2
# REACTOME_MTORC1_MEDIATED_SIGNALLING
# tailed==2
# REACTOME_ACTIVATION_OF_BH3_ONLY_PROTEINS
# tailed==2
# REACTOME_GLUCOSE_METABOLISM
# tailed==2
# REACTOME_VOLTAGE_GATED_POTASSIUM_CHANNELS
# tailed==2
# REACTOME_ADAPTIVE_IMMUNE_SYSTEM
# tailed==2
# REACTOME_NOD1_2_SIGNALING_PATHWAY
# tailed==2
# REACTOME_CYTOKINE_SIGNALING_IN_IMMUNE_SYSTEM
# tailed==2
# REACTOME_MEIOTIC_SYNAPSIS
# tailed==2
# REACTOME_ANTIGEN_PRESENTATION_FOLDING_ASSEMBLY_AND_PEPTIDE_LOADING_OF_CLASS_I_MHC
# tailed==2
# REACTOME_THE_NLRP3_INFLAMMASOME
# tailed==2
# REACTOME_CLASS_I_MHC_MEDIATED_ANTIGEN_PROCESSING_PRESENTATION
# tailed==2
# REACTOME_ANTIGEN_PROCESSING_UBIQUITINATION_PROTEASOME_DEGRADATION
# tailed==2
# REACTOME_TANDEM_PORE_DOMAIN_POTASSIUM_CHANNELS
# tailed==2
# REACTOME_INFLAMMASOMES
# tailed==2
# REACTOME_POTASSIUM_CHANNELS
# tailed==2
# REACTOME_NUCLEOTIDE_BINDING_DOMAIN_LEUCINE_RICH_REPEAT_CONTAINING_RECEPTOR_NLR_SIGNALING_PATHWAYS
# tailed==2
# REACTOME_INWARDLY_RECTIFYING_K_CHANNELS
# tailed==2
# REACTOME_TELOMERE_MAINTENANCE
# tailed==2
# REACTOME_PLATELET_ACTIVATION_SIGNALING_AND_AGGREGATION
# tailed==2
# REACTOME_REMOVAL_OF_THE_FLAP_INTERMEDIATE_FROM_THE_C_STRAND
# tailed==2
# REACTOME_CREATION_OF_C4_AND_C2_ACTIVATORS
# tailed==2
# REACTOME_APC_CDC20_MEDIATED_DEGRADATION_OF_NEK2A
# tailed==2
# REACTOME_INITIAL_TRIGGERING_OF_COMPLEMENT
# tailed==2
# REACTOME_EXTENSION_OF_TELOMERES
# tailed==2
# REACTOME_G2_M_CHECKPOINTS
# tailed==2
# REACTOME_G2_M_DNA_DAMAGE_CHECKPOINT
# tailed==2
# REACTOME_S_PHASE
# tailed==2
# REACTOME_TRYPTOPHAN_CATABOLISM
# tailed==2
# REACTOME_DNA_STRAND_ELONGATION
# tailed==2
# REACTOME_CHOLESTEROL_BIOSYNTHESIS
# tailed==2
# REACTOME_FGFR2C_LIGAND_BINDING_AND_ACTIVATION
# tailed==2
# REACTOME_METABOLISM_OF_PORPHYRINS
# tailed==2
# REACTOME_SIGNALING_BY_FGFR
# tailed==2
# REACTOME_DIGESTION_OF_DIETARY_CARBOHYDRATE
# No hits. Skipping Term.
# REACTOME_FGFR1_LIGAND_BINDING_AND_ACTIVATION
# tailed==2
# REACTOME_GAP_JUNCTION_ASSEMBLY
# tailed==2
# REACTOME_SYNTHESIS_OF_GLYCOSYLPHOSPHATIDYLINOSITOL_GPI
# tailed==2
# REACTOME_INTRINSIC_PATHWAY_FOR_APOPTOSIS
# tailed==2
# REACTOME_APOPTOTIC_EXECUTION_PHASE
# tailed==2
# REACTOME_INTERLEUKIN_6_SIGNALING
# tailed==2
# REACTOME_MAPK3_ERK1_ACTIVATION
# tailed==2
# REACTOME_TRANSLESION_SYNTHESIS_BY_Y_FAMILY_DNA_POLYMERASES_BYPASSES_LESIONS_ON_DNA_TEMPLATE
# tailed==2
# REACTOME_RECOGNITION_OF_DNA_DAMAGE_BY_PCNA_CONTAINING_REPLICATION_COMPLEX
# tailed==2
# REACTOME_TRANSLESION_SYNTHESIS_BY_POLH
# tailed==2
# REACTOME_DISPLACEMENT_OF_DNA_GLYCOSYLASE_BY_APEX1
# tailed==2
# REACTOME_POLB_DEPENDENT_LONG_PATCH_BASE_EXCISION_REPAIR
# tailed==2
# REACTOME_ACTIVATION_OF_BAD_AND_TRANSLOCATION_TO_MITOCHONDRIA
# tailed==2
# REACTOME_ACTIVATION_OF_NOXA_AND_TRANSLOCATION_TO_MITOCHONDRIA
# tailed==2
# REACTOME_BH3_ONLY_PROTEINS_ASSOCIATE_WITH_AND_INACTIVATE_ANTI_APOPTOTIC_BCL_2_MEMBERS
# tailed==2
# REACTOME_RELEASE_OF_APOPTOTIC_FACTORS_FROM_THE_MITOCHONDRIA
# tailed==2
# REACTOME_ACTIVATION_OF_CASPASES_THROUGH_APOPTOSOME_MEDIATED_CLEAVAGE
# tailed==2
# REACTOME_CYTOCHROME_C_MEDIATED_APOPTOTIC_RESPONSE
# tailed==2
# REACTOME_SMAC_XIAP_REGULATED_APOPTOTIC_RESPONSE
# tailed==2
# REACTOME_APOPTOTIC_FACTOR_MEDIATED_RESPONSE
# tailed==2
# REACTOME_CAMK_IV_MEDIATED_PHOSPHORYLATION_OF_CREB
# tailed==2
# REACTOME_G_PROTEIN_MEDIATED_EVENTS
# tailed==2
# REACTOME_PRESYNAPTIC_DEPOLARIZATION_AND_CALCIUM_CHANNEL_OPENING
# tailed==2
# REACTOME_NEUROTRANSMITTER_CLEARANCE
# tailed==2
# REACTOME_NEUROTRANSMITTER_RECEPTORS_AND_POSTSYNAPTIC_SIGNAL_TRANSMISSION
# tailed==2
# REACTOME_IRS_MEDIATED_SIGNALLING
# tailed==2
# REACTOME_RAF_INDEPENDENT_MAPK1_3_ACTIVATION
# tailed==2
# REACTOME_MAPK1_ERK2_ACTIVATION
# tailed==2
# REACTOME_FORMATION_OF_THE_EARLY_ELONGATION_COMPLEX
# tailed==2
# REACTOME_DISINHIBITION_OF_SNARE_FORMATION
# tailed==2
# REACTOME_ACTIVATION_OF_RAS_IN_B_CELLS
# tailed==2
# REACTOME_FERTILIZATION
# tailed==2
# REACTOME_ROS_AND_RNS_PRODUCTION_IN_PHAGOCYTES
# tailed==2
# REACTOME_REGULATION_OF_GENE_EXPRESSION_BY_HYPOXIA_INDUCIBLE_FACTOR
# tailed==2
# REACTOME_CELLULAR_RESPONSE_TO_HYPOXIA
# tailed==2
# REACTOME_CROSS_PRESENTATION_OF_PARTICULATE_EXOGENOUS_ANTIGENS_PHAGOSOMES
# tailed==2
# REACTOME_METHIONINE_SALVAGE_PATHWAY
# tailed==2
# REACTOME_ERYTHROCYTES_TAKE_UP_OXYGEN_AND_RELEASE_CARBON_DIOXIDE
# tailed==2
# REACTOME_SHC1_EVENTS_IN_ERBB2_SIGNALING
# tailed==2
# REACTOME_DOWNREGULATION_OF_ERBB4_SIGNALING
# tailed==2
# REACTOME_INTERLEUKIN_7_SIGNALING
# tailed==2
# REACTOME_CA2_ACTIVATED_K_CHANNELS
# tailed==2
# REACTOME_SPERM_MOTILITY_AND_TAXES
# tailed==2
# REACTOME_ACROSOME_REACTION_AND_SPERM_OOCYTE_MEMBRANE_BINDING
# tailed==2
# REACTOME_GRB7_EVENTS_IN_ERBB2_SIGNALING
# tailed==2
# REACTOME_TRANSCRIPTION_OF_E2F_TARGETS_UNDER_NEGATIVE_CONTROL_BY_DREAM_COMPLEX
# tailed==2
# REACTOME_TRANSCRIPTION_OF_E2F_TARGETS_UNDER_NEGATIVE_CONTROL_BY_P107_RBL1_AND_P130_RBL2_IN_COMPLEX_WITH_HDAC1
# tailed==2
# REACTOME_MITOCHONDRIAL_IRON_SULFUR_CLUSTER_BIOGENESIS
# tailed==2
# REACTOME_RORA_ACTIVATES_GENE_EXPRESSION
# tailed==2
# REACTOME_BMAL1_CLOCK_NPAS2_ACTIVATES_CIRCADIAN_GENE_EXPRESSION
# tailed==2
# REACTOME_ABC_TRANSPORTERS_IN_LIPID_HOMEOSTASIS
# tailed==2
# REACTOME_ELEVATION_OF_CYTOSOLIC_CA2_LEVELS
# tailed==2
# REACTOME_ACTIVATION_OF_PUMA_AND_TRANSLOCATION_TO_MITOCHONDRIA
# tailed==2
# REACTOME_CASPASE_ACTIVATION_VIA_DEATH_RECEPTORS_IN_THE_PRESENCE_OF_LIGAND
# tailed==2
# REACTOME_EXTRINSIC_PATHWAY_OF_FIBRIN_CLOT_FORMATION
# tailed==2
# REACTOME_INTRINSIC_PATHWAY_OF_FIBRIN_CLOT_FORMATION
# tailed==2
# REACTOME_COMMON_PATHWAY_OF_FIBRIN_CLOT_FORMATION
# tailed==2
# REACTOME_THE_CITRIC_ACID_TCA_CYCLE_AND_RESPIRATORY_ELECTRON_TRANSPORT
# tailed==2
# REACTOME_REGULATION_OF_SIGNALING_BY_NODAL
# tailed==2
# REACTOME_COLLAGEN_DEGRADATION
# tailed==2
# REACTOME_TRANSLOCATION_OF_SLC2A4_GLUT4_TO_THE_PLASMA_MEMBRANE
# tailed==2
# REACTOME_ALPHA_DEFENSINS
# No hits. Skipping Term.
# REACTOME_REPRODUCTION
# tailed==2
# REACTOME_ACYL_CHAIN_REMODELING_OF_CL
# tailed==2
# REACTOME_ACYL_CHAIN_REMODELING_OF_DAG_AND_TAG
# tailed==2
# REACTOME_HYDROLYSIS_OF_LPC
# tailed==2
# REACTOME_SYNTHESIS_OF_PG
# tailed==2
# REACTOME_SYNTHESIS_OF_PI
# tailed==2
# REACTOME_SYNTHESIS_OF_PIPS_AT_THE_ER_MEMBRANE
# tailed==2
# REACTOME_INOSITOL_PHOSPHATE_METABOLISM
# tailed==2
# REACTOME_SIGNALING_BY_ACTIVIN
# tailed==2
# REACTOME_PHASE_II_CONJUGATION_OF_COMPOUNDS
# tailed==2
# REACTOME_METHYLATION
# tailed==2
# REACTOME_AMINO_ACID_CONJUGATION
# tailed==2
# REACTOME_ELASTIC_FIBRE_FORMATION
# tailed==2
# REACTOME_FIBRONECTIN_MATRIX_FORMATION
# tailed==2
# REACTOME_POLO_LIKE_KINASE_MEDIATED_EVENTS
# tailed==2
# REACTOME_GAP_JUNCTION_TRAFFICKING_AND_REGULATION
# tailed==2
# REACTOME_MITOCHONDRIAL_BIOGENESIS
# tailed==2
# REACTOME_TRANSPORT_OF_THE_SLBP_DEPENDANT_MATURE_MRNA
# tailed==2
# REACTOME_TRANSPORT_OF_MATURE_MRNAS_DERIVED_FROM_INTRONLESS_TRANSCRIPTS
# tailed==2
# REACTOME_ACTIVATION_OF_MATRIX_METALLOPROTEINASES
# tailed==2
# REACTOME_REMOVAL_OF_AMINOTERMINAL_PROPEPTIDES_FROM_GAMMA_CARBOXYLATED_PROTEINS
# tailed==2
# REACTOME_ZBP1_DAI_MEDIATED_INDUCTION_OF_TYPE_I_IFNS
# tailed==2
# REACTOME_IRF3_MEDIATED_ACTIVATION_OF_TYPE_1_IFN
# tailed==2
# REACTOME_SULFIDE_OXIDATION_TO_SULFATE
# tailed==2
# REACTOME_DEGRADATION_OF_CYSTEINE_AND_HOMOCYSTEINE
# tailed==2
# REACTOME_BUDDING_AND_MATURATION_OF_HIV_VIRION
# tailed==2
# REACTOME_GOLGI_CISTERNAE_PERICENTRIOLAR_STACK_REORGANIZATION
# tailed==2
# REACTOME_ATTACHMENT_OF_GPI_ANCHOR_TO_UPAR
# tailed==2
# REACTOME_POST_TRANSLATIONAL_MODIFICATION_SYNTHESIS_OF_GPI_ANCHORED_PROTEINS
# tailed==2
# REACTOME_PKA_MEDIATED_PHOSPHORYLATION_OF_KEY_METABOLIC_FACTORS
# tailed==2
# REACTOME_TRIGLYCERIDE_CATABOLISM
# tailed==2
# REACTOME_AMPK_INHIBITS_CHREBP_TRANSCRIPTIONAL_ACTIVATION_ACTIVITY
# tailed==2
# REACTOME_CHREBP_ACTIVATES_METABOLIC_GENE_EXPRESSION
# tailed==2
# REACTOME_PP2A_MEDIATED_DEPHOSPHORYLATION_OF_KEY_METABOLIC_FACTORS
# tailed==2
# REACTOME_GAMMA_CARBOXYLATION_HYPUSINE_FORMATION_AND_ARYLSULFATASE_ACTIVATION
# tailed==2
# REACTOME_DISEASE
# tailed==2
# REACTOME_PKA_ACTIVATION_IN_GLUCAGON_SIGNALLING
# tailed==2
# REACTOME_2_LTR_CIRCLE_FORMATION
# tailed==2
# REACTOME_NEF_AND_SIGNAL_TRANSDUCTION
# tailed==2
# REACTOME_THE_ROLE_OF_NEF_IN_HIV_1_REPLICATION_AND_DISEASE_PATHOGENESIS
# tailed==2
# REACTOME_COLLAGEN_BIOSYNTHESIS_AND_MODIFYING_ENZYMES
# tailed==2
# REACTOME_MTOR_SIGNALLING
# tailed==2
# REACTOME_REGULATION_OF_CHOLESTEROL_BIOSYNTHESIS_BY_SREBP_SREBF
# tailed==2
# REACTOME_TOLL_LIKE_RECEPTOR_4_TLR4_CASCADE
# tailed==2
# REACTOME_MITOCHONDRIAL_UNCOUPLING
# tailed==2
# REACTOME_SIGNALING_BY_NTRKS
# tailed==2
# REACTOME_LECTIN_PATHWAY_OF_COMPLEMENT_ACTIVATION
# No hits. Skipping Term.
# REACTOME_TERMINAL_PATHWAY_OF_COMPLEMENT
# tailed==2
# REACTOME_TRANSCRIPTION_OF_THE_HIV_GENOME
# tailed==2
# REACTOME_ABORTIVE_ELONGATION_OF_HIV_1_TRANSCRIPT_IN_THE_ABSENCE_OF_TAT
# tailed==2
# REACTOME_HIV_ELONGATION_ARREST_AND_RECOVERY
# tailed==2
# REACTOME_NEF_MEDIATED_CD4_DOWN_REGULATION
# tailed==2
# REACTOME_TOLL_LIKE_RECEPTOR_9_TLR9_CASCADE
# tailed==2
# REACTOME_TOLL_LIKE_RECEPTOR_TLR1_TLR2_CASCADE
# tailed==2
# REACTOME_INFLUENZA_INFECTION
# tailed==2
# REACTOME_EXPORT_OF_VIRAL_RIBONUCLEOPROTEINS_FROM_NUCLEUS
# tailed==2
# REACTOME_NEUROTOXICITY_OF_CLOSTRIDIUM_TOXINS
# tailed==2
# REACTOME_TOLL_LIKE_RECEPTOR_CASCADES
# tailed==2
# REACTOME_TICAM1_RIP1_MEDIATED_IKK_COMPLEX_RECRUITMENT
# tailed==2
# REACTOME_DDX58_IFIH1_MEDIATED_INDUCTION_OF_INTERFERON_ALPHA_BETA
# tailed==2
# REACTOME_TELOMERE_EXTENSION_BY_TELOMERASE
# tailed==2
# REACTOME_ALTERNATIVE_COMPLEMENT_ACTIVATION
# tailed==2
# REACTOME_TRANSPORT_AND_SYNTHESIS_OF_PAPS
# tailed==2
# REACTOME_GLUTATHIONE_SYNTHESIS_AND_RECYCLING
# tailed==2
# REACTOME_PROCESSIVE_SYNTHESIS_ON_THE_C_STRAND_OF_THE_TELOMERE
# tailed==2
# REACTOME_TELOMERE_C_STRAND_LAGGING_STRAND_SYNTHESIS
# tailed==2
# REACTOME_ACTIVATION_OF_C3_AND_C5
# tailed==2
# REACTOME_PLASMA_LIPOPROTEIN_ASSEMBLY_REMODELING_AND_CLEARANCE
# tailed==2
# REACTOME_ASSEMBLY_OF_THE_HIV_VIRION
# tailed==2
# REACTOME_PHOSPHORYLATION_OF_EMI1
# tailed==2
# REACTOME_CONJUGATION_OF_BENZOATE_WITH_GLYCINE
# No hits. Skipping Term.
# REACTOME_INTERACTIONS_OF_REV_WITH_HOST_CELLULAR_PROTEINS
# tailed==2
# REACTOME_SIGNALING_BY_EGFR
# tailed==2
# REACTOME_APOBEC3G_MEDIATED_RESISTANCE_TO_HIV_1_INFECTION
# tailed==2
# REACTOME_NUCLEAR_IMPORT_OF_REV_PROTEIN
# tailed==2
# REACTOME_RIP_MEDIATED_NFKB_ACTIVATION_VIA_ZBP1
# tailed==2
# REACTOME_SEROTONIN_NEUROTRANSMITTER_RELEASE_CYCLE
# tailed==2
# REACTOME_NEF_MEDIATED_CD8_DOWN_REGULATION
# tailed==2
# REACTOME_STING_MEDIATED_INDUCTION_OF_HOST_IMMUNE_RESPONSES
# tailed==2
# REACTOME_CYTOSOLIC_SENSORS_OF_PATHOGEN_ASSOCIATED_DNA
# tailed==2
# REACTOME_SIGNALING_BY_CYTOSOLIC_FGFR1_FUSION_MUTANTS
# tailed==2
# REACTOME_FGFR1_MUTANT_RECEPTOR_ACTIVATION
# tailed==2
# REACTOME_FGFR2_MUTANT_RECEPTOR_ACTIVATION
# tailed==2
# REACTOME_ORGANELLE_BIOGENESIS_AND_MAINTENANCE
# tailed==2
# REACTOME_SYNTHESIS_OF_PYROPHOSPHATES_IN_THE_CYTOSOL
# tailed==2
# REACTOME_SYNTHESIS_OF_IP2_IP_AND_INS_IN_THE_CYTOSOL
# tailed==2
# REACTOME_SYNTHESIS_OF_IP3_AND_IP4_IN_THE_CYTOSOL
# tailed==2
# REACTOME_ACTIVATION_OF_TRKA_RECEPTORS
# tailed==2
# REACTOME_NGF_INDEPENDANT_TRKA_ACTIVATION
# tailed==2
# REACTOME_SCF_SKP2_MEDIATED_DEGRADATION_OF_P27_P21
# tailed==2
# REACTOME_CELLULAR_HEXOSE_TRANSPORT
# tailed==2
# REACTOME_HEME_BIOSYNTHESIS
# tailed==2
# REACTOME_HEME_DEGRADATION
# tailed==2
# REACTOME_FGFR3_LIGAND_BINDING_AND_ACTIVATION
# tailed==2
# REACTOME_FGFR2_LIGAND_BINDING_AND_ACTIVATION
# tailed==2
# REACTOME_FGFR1B_LIGAND_BINDING_AND_ACTIVATION
# tailed==2
# REACTOME_FGFR3B_LIGAND_BINDING_AND_ACTIVATION
# tailed==2
# REACTOME_FGFR1C_LIGAND_BINDING_AND_ACTIVATION
# tailed==2
# REACTOME_FGFR2B_LIGAND_BINDING_AND_ACTIVATION
# tailed==2
# REACTOME_TRANSPORT_OF_CONNEXONS_TO_THE_PLASMA_MEMBRANE
# tailed==2
# REACTOME_PRE_NOTCH_PROCESSING_IN_THE_ENDOPLASMIC_RETICULUM
# tailed==2
# REACTOME_DIGESTION_OF_DIETARY_LIPID
# No hits. Skipping Term.
# REACTOME_ESTROGEN_BIOSYNTHESIS
# tailed==2
# REACTOME_P75NTR_SIGNALS_VIA_NF_KB
# tailed==2
# REACTOME_P75NTR_NEGATIVELY_REGULATES_CELL_CYCLE_VIA_SC1
# tailed==2
# REACTOME_P75NTR_REGULATES_AXONOGENESIS
# tailed==2
# REACTOME_SYNTHESIS_OF_BILE_ACIDS_AND_BILE_SALTS_VIA_27_HYDROXYCHOLESTEROL
# tailed==2
# REACTOME_MINERALOCORTICOID_BIOSYNTHESIS
# No hits. Skipping Term.
# REACTOME_GLUCOCORTICOID_BIOSYNTHESIS
# No hits. Skipping Term.
# REACTOME_SIGNALING_BY_VEGF
# tailed==2
# REACTOME_RHO_GTPASE_CYCLE
# tailed==2
# REACTOME_DEGRADATION_OF_BETA_CATENIN_BY_THE_DESTRUCTION_COMPLEX
# tailed==2
# REACTOME_RHO_GTPASE_EFFECTORS
# tailed==2
# REACTOME_METABOLISM_OF_STEROID_HORMONES
# tailed==2
# REACTOME_PREGNENOLONE_BIOSYNTHESIS
# tailed==2
# REACTOME_BETA_CATENIN_PHOSPHORYLATION_CASCADE
# tailed==2
# REACTOME_COBALAMIN_CBL_VITAMIN_B12_TRANSPORT_AND_METABOLISM
# tailed==2
# REACTOME_METABOLISM_OF_FOLATE_AND_PTERINES
# tailed==2
# REACTOME_BIOTIN_TRANSPORT_AND_METABOLISM
# tailed==2
# REACTOME_COENZYME_A_BIOSYNTHESIS
# tailed==2
# REACTOME_VITAMIN_D_CALCIFEROL_METABOLISM
# tailed==2
# REACTOME_NICOTINATE_METABOLISM
# tailed==2
# REACTOME_VITAMIN_B1_THIAMIN_METABOLISM
# tailed==2
# REACTOME_VITAMIN_C_ASCORBATE_METABOLISM
# tailed==2
# REACTOME_VITAMIN_B2_RIBOFLAVIN_METABOLISM
# tailed==2
# REACTOME_METABOLISM_OF_WATER_SOLUBLE_VITAMINS_AND_COFACTORS
# tailed==2
# REACTOME_NICOTINAMIDE_SALVAGING
# tailed==2
# REACTOME_AKT_PHOSPHORYLATES_TARGETS_IN_THE_NUCLEUS
# tailed==2
# REACTOME_CREB_PHOSPHORYLATION
# tailed==2
# REACTOME_ER_TO_GOLGI_ANTEROGRADE_TRANSPORT
# tailed==2
# REACTOME_CARNITINE_METABOLISM
# tailed==2
# REACTOME_TCF_DEPENDENT_SIGNALING_IN_RESPONSE_TO_WNT
# tailed==2
# REACTOME_WNT_MEDIATED_ACTIVATION_OF_DVL
# tailed==2
# REACTOME_FORMATION_OF_THE_BETA_CATENIN_TCF_TRANSACTIVATING_COMPLEX
# tailed==2
# REACTOME_METABOLISM_OF_NITRIC_OXIDE_ENOS_ACTIVATION_AND_REGULATION
# tailed==2
# REACTOME_ASSEMBLY_OF_COLLAGEN_FIBRILS_AND_OTHER_MULTIMERIC_STRUCTURES
# tailed==2
# REACTOME_METABOLISM_OF_ANGIOTENSINOGEN_TO_ANGIOTENSINS
# tailed==2
# REACTOME_DERMATAN_SULFATE_BIOSYNTHESIS
# tailed==2
# REACTOME_CALCINEURIN_ACTIVATES_NFAT
# tailed==2
# REACTOME_FCGAMMA_RECEPTOR_FCGR_DEPENDENT_PHAGOCYTOSIS
# tailed==2
# REACTOME_FCGR_ACTIVATION
# tailed==2
# REACTOME_ROLE_OF_PHOSPHOLIPIDS_IN_PHAGOCYTOSIS
# tailed==2
# REACTOME_ENOS_ACTIVATION
# tailed==2
# REACTOME_NOSTRIN_MEDIATED_ENOS_TRAFFICKING
# tailed==2
# REACTOME_COPII_MEDIATED_VESICLE_TRANSPORT
# tailed==2
# REACTOME_ALPHA_LINOLENIC_OMEGA3_AND_LINOLEIC_OMEGA6_ACID_METABOLISM
# tailed==2
# REACTOME_LINOLEIC_ACID_LA_METABOLISM
# tailed==2
# REACTOME_NADE_MODULATES_DEATH_SIGNALLING
# tailed==2
# REACTOME_NF_KB_IS_ACTIVATED_AND_SIGNALS_SURVIVAL
# tailed==2
# REACTOME_METABOLISM_OF_AMINE_DERIVED_HORMONES
# tailed==2
# REACTOME_SEROTONIN_AND_MELATONIN_BIOSYNTHESIS
# tailed==2
# REACTOME_THYROXINE_BIOSYNTHESIS
# tailed==2
# REACTOME_REGULATION_OF_GENE_EXPRESSION_IN_LATE_STAGE_BRANCHING_MORPHOGENESIS_PANCREATIC_BUD_PRECURSOR_CELLS
# tailed==2
# REACTOME_REGULATION_OF_GENE_EXPRESSION_IN_ENDOCRINE_COMMITTED_NEUROG3_PROGENITOR_CELLS
# No hits. Skipping Term.
# REACTOME_REGULATION_OF_GENE_EXPRESSION_IN_EARLY_PANCREATIC_PRECURSOR_CELLS
# No hits. Skipping Term.
# REACTOME_GENE_SILENCING_BY_RNA
# tailed==2
# REACTOME_VITAMINS
# tailed==2
# REACTOME_FATTY_ACIDS
# tailed==2
# REACTOME_PHASE_I_FUNCTIONALIZATION_OF_COMPOUNDS
# tailed==2
# REACTOME_MISCELLANEOUS_SUBSTRATES
# tailed==2
# REACTOME_EICOSANOIDS
# tailed==2
# REACTOME_CYP2E1_REACTIONS
# No hits. Skipping Term.
# REACTOME_EPIGENETIC_REGULATION_OF_GENE_EXPRESSION
# tailed==2
# REACTOME_PRC2_METHYLATES_HISTONES_AND_DNA
# tailed==2
# REACTOME_EGFR_INTERACTS_WITH_PHOSPHOLIPASE_C_GAMMA
# tailed==2
# REACTOME_MOLECULES_ASSOCIATED_WITH_ELASTIC_FIBRES
# tailed==2
# REACTOME_SYNTHESIS_OF_EPOXY_EET_AND_DIHYDROXYEICOSATRIENOIC_ACIDS_DHET
# tailed==2
# REACTOME_SYNTHESIS_OF_5_EICOSATETRAENOIC_ACIDS
# tailed==2
# REACTOME_SYNTHESIS_OF_LEUKOTRIENES_LT_AND_EOXINS_EX
# tailed==2
# REACTOME_SYNTHESIS_OF_LIPOXINS_LX
# tailed==2
# REACTOME_SYNTHESIS_OF_12_EICOSATETRAENOIC_ACID_DERIVATIVES
# tailed==2
# REACTOME_ARACHIDONIC_ACID_METABOLISM
# tailed==2
# REACTOME_SYNTHESIS_OF_15_EICOSATETRAENOIC_ACID_DERIVATIVES
# tailed==2
# REACTOME_UBIQUINOL_BIOSYNTHESIS
# tailed==2
# REACTOME_SYNTHESIS_OF_16_20_HYDROXYEICOSATETRAENOIC_ACIDS_HETE
# tailed==2
# REACTOME_HYALURONAN_BIOSYNTHESIS_AND_EXPORT
# tailed==2
# REACTOME_TRANSCRIPTIONAL_ACTIVATION_OF_MITOCHONDRIAL_BIOGENESIS
# tailed==2
# REACTOME_ACTIVATION_OF_PPARGC1A_PGC_1ALPHA_BY_PHOSPHORYLATION
# tailed==2
# REACTOME_ABACAVIR_TRANSMEMBRANE_TRANSPORT
# No hits. Skipping Term.
# REACTOME_ABACAVIR_METABOLISM
# tailed==2
# REACTOME_SYNTHESIS_OF_PROSTAGLANDINS_PG_AND_THROMBOXANES_TX
# tailed==2
# REACTOME_SCAVENGING_OF_HEME_FROM_PLASMA
# tailed==2
# REACTOME_DAP12_INTERACTIONS
# tailed==2
# REACTOME_BINDING_AND_UPTAKE_OF_LIGANDS_BY_SCAVENGER_RECEPTORS
# tailed==2
# REACTOME_EGFR_TRANSACTIVATION_BY_GASTRIN
# tailed==2
# REACTOME_THE_RETINOID_CYCLE_IN_CONES_DAYLIGHT_VISION
# tailed==2
# REACTOME_VISUAL_PHOTOTRANSDUCTION
# tailed==2
# REACTOME_NOTCH2_INTRACELLULAR_DOMAIN_REGULATES_TRANSCRIPTION
# tailed==2
# REACTOME_MUCOPOLYSACCHARIDOSES
# tailed==2
# REACTOME_ANCHORING_FIBRIL_FORMATION
# tailed==2
# REACTOME_PI3K_AKT_SIGNALING_IN_CANCER
# tailed==2
# REACTOME_CONSTITUTIVE_SIGNALING_BY_ABERRANT_PI3K_IN_CANCER
# tailed==2
# REACTOME_CROSSLINKING_OF_COLLAGEN_FIBRILS
# tailed==2
# REACTOME_CONDENSATION_OF_PROPHASE_CHROMOSOMES
# tailed==2
# REACTOME_PHOSPHATE_BOND_HYDROLYSIS_BY_NUDT_PROTEINS
# tailed==2
# REACTOME_SIGNALING_BY_TYPE_1_INSULIN_LIKE_GROWTH_FACTOR_1_RECEPTOR_IGF1R
# tailed==2
# REACTOME_METABOLISM_OF_INGESTED_SEMET_SEC_MESEC_INTO_H2SE
# tailed==2
# REACTOME_SELENOAMINO_ACID_METABOLISM
# tailed==2
# REACTOME_DAP12_SIGNALING
# tailed==2
# REACTOME_ACTIVATION_OF_GENE_EXPRESSION_BY_SREBF_SREBP
# tailed==2
# REACTOME_SHC_RELATED_EVENTS_TRIGGERED_BY_IGF1R
# tailed==2
# REACTOME_THE_CANONICAL_RETINOID_CYCLE_IN_RODS_TWILIGHT_VISION
# tailed==2
# REACTOME_FC_EPSILON_RECEPTOR_FCERI_SIGNALING
# tailed==2
# REACTOME_MASTL_FACILITATES_MITOTIC_PROGRESSION
# tailed==2
# REACTOME_ESTABLISHMENT_OF_SISTER_CHROMATID_COHESION
# tailed==2
# REACTOME_COHESIN_LOADING_ONTO_CHROMATIN
# tailed==2
# REACTOME_ACTIVATION_OF_THE_PHOTOTRANSDUCTION_CASCADE
# tailed==2
# REACTOME_RESOLUTION_OF_SISTER_CHROMATID_COHESION
# tailed==2
# REACTOME_CONDENSATION_OF_PROMETAPHASE_CHROMOSOMES
# tailed==2
# REACTOME_THE_PHOTOTRANSDUCTION_CASCADE
# tailed==2
# REACTOME_INTERACTION_WITH_CUMULUS_CELLS_AND_THE_ZONA_PELLUCIDA
# tailed==2
# REACTOME_MITOTIC_METAPHASE_AND_ANAPHASE
# tailed==2
# REACTOME_OXIDATIVE_STRESS_INDUCED_SENESCENCE
# tailed==2
# REACTOME_SENESCENCE_ASSOCIATED_SECRETORY_PHENOTYPE_SASP
# tailed==2
# REACTOME_CELLULAR_SENESCENCE
# tailed==2
# REACTOME_FORMATION_OF_SENESCENCE_ASSOCIATED_HETEROCHROMATIN_FOCI_SAHF
# tailed==2
# REACTOME_ONCOGENE_INDUCED_SENESCENCE
# tailed==2
# REACTOME_DNA_DAMAGE_TELOMERE_STRESS_INDUCED_SENESCENCE
# tailed==2
# REACTOME_TRIF_MEDIATED_PROGRAMMED_CELL_DEATH
# tailed==2
# REACTOME_CYTOSOLIC_IRON_SULFUR_CLUSTER_ASSEMBLY
# tailed==2
# REACTOME_REGULATION_OF_PLK1_ACTIVITY_AT_G2_M_TRANSITION
# tailed==2
# REACTOME_SIGNALING_BY_LEPTIN
# tailed==2
# REACTOME_FBXW7_MUTANTS_AND_NOTCH1_IN_CANCER
# tailed==2
# REACTOME_INSULIN_PROCESSING
# tailed==2
# REACTOME_SIGNALING_BY_NOTCH1_T_7_9_NOTCH1_M1580_K2555_TRANSLOCATION_MUTANT
# tailed==2
# REACTOME_STIMULI_SENSING_CHANNELS
# tailed==2
# REACTOME_EPH_EPHRIN_SIGNALING
# tailed==2
# REACTOME_SIGNALING_BY_NOTCH1_HD_DOMAIN_MUTANTS_IN_CANCER
# tailed==2
# REACTOME_ROLE_OF_LAT2_NTAL_LAB_ON_CALCIUM_MOBILIZATION
# tailed==2
# REACTOME_FICOLINS_BIND_TO_REPETITIVE_CARBOHYDRATE_STRUCTURES_ON_THE_TARGET_CELL_SURFACE
# No hits. Skipping Term.
# REACTOME_FCERI_MEDIATED_MAPK_ACTIVATION
# tailed==2
# REACTOME_FCERI_MEDIATED_CA_2_MOBILIZATION
# tailed==2
# REACTOME_FCERI_MEDIATED_NF_KB_ACTIVATION
# tailed==2
# REACTOME_POU5F1_OCT4_SOX2_NANOG_REPRESS_GENES_RELATED_TO_DIFFERENTIATION
# tailed==2
# REACTOME_POU5F1_OCT4_SOX2_NANOG_ACTIVATE_GENES_RELATED_TO_PROLIFERATION
# tailed==2
# REACTOME_NOTCH2_ACTIVATION_AND_TRANSMISSION_OF_SIGNAL_TO_THE_NUCLEUS
# tailed==2
# REACTOME_PEPTIDE_HORMONE_METABOLISM
# tailed==2
# REACTOME_NUCLEAR_ENVELOPE_BREAKDOWN
# tailed==2
# REACTOME_ACTIVATION_OF_NIMA_KINASES_NEK9_NEK6_NEK7
# tailed==2
# REACTOME_SUMOYLATION
# tailed==2
# REACTOME_NUCLEAR_ENVELOPE_NE_REASSEMBLY
# tailed==2
# REACTOME_LAMININ_INTERACTIONS
# tailed==2
# REACTOME_SYNDECAN_INTERACTIONS
# tailed==2
# REACTOME_NON_INTEGRIN_MEMBRANE_ECM_INTERACTIONS
# tailed==2
# REACTOME_ECM_PROTEOGLYCANS
# tailed==2
# REACTOME_SCAVENGING_BY_CLASS_B_RECEPTORS
# tailed==2
# REACTOME_SCAVENGING_BY_CLASS_A_RECEPTORS
# tailed==2
# REACTOME_SCAVENGING_BY_CLASS_F_RECEPTORS
# tailed==2
# REACTOME_SUMO_IS_CONJUGATED_TO_E1_UBA2_SAE1
# tailed==2
# REACTOME_SUMO_IS_TRANSFERRED_FROM_E1_TO_E2_UBE2I_UBC9
# tailed==2
# REACTOME_SUMO_IS_PROTEOLYTICALLY_PROCESSED
# tailed==2
# REACTOME_SUMOYLATION_OF_DNA_DAMAGE_RESPONSE_AND_REPAIR_PROTEINS
# tailed==2
# REACTOME_DEX_H_BOX_HELICASES_ACTIVATE_TYPE_I_IFN_AND_INFLAMMATORY_CYTOKINES_PRODUCTION
# tailed==2
# REACTOME_LRR_FLII_INTERACTING_PROTEIN_1_LRRFIP1_ACTIVATES_TYPE_I_IFN_PRODUCTION
# tailed==2
# REACTOME_REGULATION_OF_INNATE_IMMUNE_RESPONSES_TO_CYTOSOLIC_DNA
# tailed==2
# REACTOME_HDACS_DEACETYLATE_HISTONES
# tailed==2
# REACTOME_PKMTS_METHYLATE_HISTONE_LYSINES
# tailed==2
# REACTOME_HDMS_DEMETHYLATE_HISTONES
# tailed==2
# REACTOME_HATS_ACETYLATE_HISTONES
# tailed==2
# REACTOME_RMTS_METHYLATE_HISTONE_ARGININES
# tailed==2
# REACTOME_PROCESSING_AND_ACTIVATION_OF_SUMO
# tailed==2
# REACTOME_GLYCOGEN_STORAGE_DISEASES
# tailed==2
# REACTOME_SUMOYLATION_OF_TRANSCRIPTION_FACTORS
# tailed==2
# REACTOME_SUMOYLATION_OF_UBIQUITINYLATION_PROTEINS
# tailed==2
# REACTOME_WNT_LIGAND_BIOGENESIS_AND_TRAFFICKING
# tailed==2
# REACTOME_IRF3_MEDIATED_INDUCTION_OF_TYPE_I_IFN
# tailed==2
# REACTOME_TRP_CHANNELS
# tailed==2
# REACTOME_DEFECTS_IN_COBALAMIN_B12_METABOLISM
# tailed==2
# REACTOME_DEFECTS_IN_VITAMIN_AND_COFACTOR_METABOLISM
# tailed==2
# REACTOME_DETOXIFICATION_OF_REACTIVE_OXYGEN_SPECIES
# tailed==2
# REACTOME_NUCLEAR_PORE_COMPLEX_NPC_DISASSEMBLY
# tailed==2
# REACTOME_SIGNALING_BY_TGF_BETA_RECEPTOR_COMPLEX_IN_CANCER
# tailed==2
# REACTOME_GLYCOGEN_SYNTHESIS
# tailed==2
# REACTOME_DEFECTS_IN_BIOTIN_BTN_METABOLISM
# tailed==2
# REACTOME_REGULATION_BY_C_FLIP
# tailed==2
# REACTOME_REGULATION_OF_HSF1_MEDIATED_HEAT_SHOCK_RESPONSE
# tailed==2
# REACTOME_HSP90_CHAPERONE_CYCLE_FOR_STEROID_HORMONE_RECEPTORS_SHR
# tailed==2
# REACTOME_HSF1_ACTIVATION
# tailed==2
# REACTOME_CELLULAR_RESPONSE_TO_HEAT_STRESS
# tailed==2
# REACTOME_ATTENUATION_PHASE
# tailed==2
# REACTOME_HSF1_DEPENDENT_TRANSACTIVATION
# tailed==2
# REACTOME_GRB2_SOS_PROVIDES_LINKAGE_TO_MAPK_SIGNALING_FOR_INTEGRINS
# tailed==2
# REACTOME_DISEASES_ASSOCIATED_WITH_GLYCOSAMINOGLYCAN_METABOLISM
# tailed==2
# REACTOME_DEFECTIVE_B4GALT7_CAUSES_EDS_PROGEROID_TYPE
# tailed==2
# REACTOME_DEFECTIVE_CHST3_CAUSES_SEDCJD
# tailed==2
# REACTOME_DEFECTIVE_CHST14_CAUSES_EDS_MUSCULOCONTRACTURAL_TYPE
# tailed==2
# REACTOME_DEFECTIVE_CHSY1_CAUSES_TPBS
# tailed==2
# REACTOME_DEFECTIVE_CHST6_CAUSES_MCDC1
# tailed==2
# REACTOME_DEFECTIVE_EXT2_CAUSES_EXOSTOSES_2
# tailed==2
# REACTOME_DEFECTIVE_ST3GAL3_CAUSES_MCT12_AND_EIEE15
# tailed==2
# REACTOME_DEFECTIVE_B4GALT1_CAUSES_B4GALT1_CDG_CDG_2D
# tailed==2
# REACTOME_TRANSCRIPTIONAL_REGULATION_BY_TP53
# tailed==2
# REACTOME_CLASS_A_1_RHODOPSIN_LIKE_RECEPTORS
# tailed==2
# REACTOME_NETRIN_1_SIGNALING
# tailed==2
# REACTOME_NEPHRIN_FAMILY_INTERACTIONS
# tailed==2
# REACTOME_SIGNALING_BY_ROBO_RECEPTORS
# tailed==2
# REACTOME_DEACTIVATION_OF_THE_BETA_CATENIN_TRANSACTIVATING_COMPLEX
# tailed==2
# REACTOME_NEGATIVE_REGULATION_OF_TCF_DEPENDENT_SIGNALING_BY_WNT_LIGAND_ANTAGONISTS
# tailed==2
# REACTOME_DISEASES_ASSOCIATED_WITH_N_GLYCOSYLATION_OF_PROTEINS
# tailed==2
# REACTOME_DISEASES_OF_GLYCOSYLATION
# tailed==2
# REACTOME_MYOCLONIC_EPILEPSY_OF_LAFORA
# tailed==2
# REACTOME_TACHYKININ_RECEPTORS_BIND_TACHYKININS
# No hits. Skipping Term.
# REACTOME_ATF4_ACTIVATES_GENES_IN_RESPONSE_TO_ENDOPLASMIC_RETICULUM_STRESS
# tailed==2
# REACTOME_ATF6_ATF6_ALPHA_ACTIVATES_CHAPERONES
# tailed==2
# REACTOME_PERK_REGULATES_GENE_EXPRESSION
# tailed==2
# REACTOME_IRE1ALPHA_ACTIVATES_CHAPERONES
# tailed==2
# REACTOME_UNFOLDED_PROTEIN_RESPONSE_UPR
# tailed==2
# REACTOME_ATF6_ATF6_ALPHA_ACTIVATES_CHAPERONE_GENES
# tailed==2
# REACTOME_REGULATION_OF_INSULIN_LIKE_GROWTH_FACTOR_IGF_TRANSPORT_AND_UPTAKE_BY_INSULIN_LIKE_GROWTH_FACTOR_BINDING_PROTEINS_IGFBPS
# tailed==2
# REACTOME_GLUCAGON_LIKE_PEPTIDE_1_GLP1_REGULATES_INSULIN_SECRETION
# tailed==2
# REACTOME_TRANSPORT_OF_SMALL_MOLECULES
# tailed==2
# REACTOME_BETA_CATENIN_INDEPENDENT_WNT_SIGNALING
# tailed==2
# REACTOME_VASOPRESSIN_LIKE_RECEPTORS
# tailed==2
# REACTOME_RECEPTOR_TYPE_TYROSINE_PROTEIN_PHOSPHATASES
# tailed==2
# REACTOME_OREXIN_AND_NEUROPEPTIDES_FF_AND_QRFP_BIND_TO_THEIR_RESPECTIVE_RECEPTORS
# tailed==2
# REACTOME_ALPHA_OXIDATION_OF_PHYTANATE
# tailed==2
# REACTOME_GLYOXYLATE_METABOLISM_AND_GLYCINE_DEGRADATION
# tailed==2
# REACTOME_BETA_OXIDATION_OF_PRISTANOYL_COA
# tailed==2
# REACTOME_SUMOYLATION_OF_TRANSCRIPTION_COFACTORS
# tailed==2
# REACTOME_PD_1_SIGNALING
# tailed==2
# REACTOME_COOPERATION_OF_PREFOLDIN_AND_TRIC_CCT_IN_ACTIN_AND_TUBULIN_FOLDING
# tailed==2
# REACTOME_BETA_OXIDATION_OF_VERY_LONG_CHAIN_FATTY_ACIDS
# tailed==2
# REACTOME_FOLDING_OF_ACTIN_BY_CCT_TRIC
# tailed==2
# REACTOME_MUSCARINIC_ACETYLCHOLINE_RECEPTORS
# tailed==2
# REACTOME_DOPAMINE_RECEPTORS
# tailed==2
# REACTOME_ADRENOCEPTORS
# No hits. Skipping Term.
# REACTOME_DISEASES_ASSOCIATED_WITH_O_GLYCOSYLATION_OF_PROTEINS
# tailed==2
# REACTOME_SIGNAL_REGULATORY_PROTEIN_FAMILY_INTERACTIONS
# tailed==2
# REACTOME_LEUKOTRIENE_RECEPTORS
# tailed==2
# REACTOME_ADP_SIGNALLING_THROUGH_P2Y_PURINOCEPTOR_12
# tailed==2
# REACTOME_EPHB_MEDIATED_FORWARD_SIGNALING
# tailed==2
# REACTOME_EPHA_MEDIATED_GROWTH_CONE_COLLAPSE
# tailed==2
# REACTOME_EPHRIN_SIGNALING
# tailed==2
# REACTOME_EPH_EPHRIN_MEDIATED_REPULSION_OF_CELLS
# tailed==2
# REACTOME_ACETYLCHOLINE_REGULATES_INSULIN_SECRETION
# tailed==2
# REACTOME_ADRENALINE_NORADRENALINE_INHIBITS_INSULIN_SECRETION
# tailed==2
# REACTOME_REGULATION_OF_LIPID_METABOLISM_BY_PPARALPHA
# tailed==2
# REACTOME_FREE_FATTY_ACIDS_REGULATE_INSULIN_SECRETION
# tailed==2
# REACTOME_SYNTHESIS_SECRETION_AND_INACTIVATION_OF_GLUCOSE_DEPENDENT_INSULINOTROPIC_POLYPEPTIDE_GIP
# tailed==2
# REACTOME_SIALIC_ACID_METABOLISM
# tailed==2
# REACTOME_SUMOYLATION_OF_SUMOYLATION_PROTEINS
# tailed==2
# REACTOME_CA2_PATHWAY
# tailed==2
# REACTOME_PCP_CE_PATHWAY
# tailed==2
# REACTOME_SUMOYLATION_OF_INTRACELLULAR_RECEPTORS
# tailed==2
# REACTOME_G_ALPHA_12_13_SIGNALLING_EVENTS
# tailed==2
# REACTOME_SEMA4D_MEDIATED_INHIBITION_OF_CELL_ATTACHMENT_AND_MIGRATION
# tailed==2
# REACTOME_REDUCTION_OF_CYTOSOLIC_CA_LEVELS
# tailed==2
# REACTOME_ADP_SIGNALLING_THROUGH_P2Y_PURINOCEPTOR_1
# tailed==2
# REACTOME_NETRIN_MEDIATED_REPULSION_SIGNALS
# tailed==2
# REACTOME_CASPASE_ACTIVATION_VIA_DEPENDENCE_RECEPTORS_IN_THE_ABSENCE_OF_LIGAND
# tailed==2
# REACTOME_ROLE_OF_SECOND_MESSENGERS_IN_NETRIN_1_SIGNALING
# tailed==2
# REACTOME_LYSOSPHINGOLIPID_AND_LPA_RECEPTORS
# tailed==2
# REACTOME_CALCITONIN_LIKE_LIGAND_RECEPTORS
# tailed==2
# REACTOME_NECTIN_NECL_TRANS_HETERODIMERIZATION
# tailed==2
# REACTOME_TRANSPORT_OF_BILE_SALTS_AND_ORGANIC_ACIDS_METAL_IONS_AND_AMINE_COMPOUNDS
# tailed==2
# REACTOME_BICARBONATE_TRANSPORTERS
# tailed==2
# REACTOME_SODIUM_CALCIUM_EXCHANGERS
# tailed==2
# REACTOME_SODIUM_PROTON_EXCHANGERS
# tailed==2
# REACTOME_ARACHIDONATE_PRODUCTION_FROM_DAG
# tailed==2
# REACTOME_CATION_COUPLED_CHLORIDE_COTRANSPORTERS
# tailed==2
# ...
# tailed==2
# REACTOME_E3_UBIQUITIN_LIGASES_UBIQUITINATE_TARGET_PROTEINS
# tailed==2
# REACTOME_NEGATIVE_REGULATION_OF_ACTIVITY_OF_TFAP2_AP_2_FAMILY_TRANSCRIPTION_FACTORS
# tailed==2
# REACTOME_ACTIVATION_OF_THE_TFAP2_AP_2_FAMILY_OF_TRANSCRIPTION_FACTORS
# tailed==2
# REACTOME_TFAP2_AP_2_FAMILY_REGULATES_TRANSCRIPTION_OF_GROWTH_FACTORS_AND_THEIR_RECEPTORS
# tailed==2
# REACTOME_TFAP2_AP_2_FAMILY_REGULATES_TRANSCRIPTION_OF_CELL_CYCLE_FACTORS
# tailed==2
# REACTOME_RRNA_PROCESSING_IN_THE_MITOCHONDRION
# tailed==2
# REACTOME_TFAP2A_ACTS_AS_A_TRANSCRIPTIONAL_REPRESSOR_DURING_RETINOIC_ACID_INDUCED_CELL_DIFFERENTIATION
# tailed==2
# REACTOME_RAB_GERANYLGERANYLATION
# tailed==2
# REACTOME_MET_ACTIVATES_PTK2_SIGNALING
# tailed==2
# REACTOME_CREB3_FACTORS_ACTIVATE_GENES
# tailed==2
# REACTOME_INLB_MEDIATED_ENTRY_OF_LISTERIA_MONOCYTOGENES_INTO_HOST_CELL
# tailed==2
# REACTOME_MET_INTERACTS_WITH_TNS_PROTEINS
# tailed==2
# REACTOME_MET_ACTIVATES_RAP1_AND_RAC1
# tailed==2
# REACTOME_MET_RECEPTOR_RECYCLING
# tailed==2
# REACTOME_MET_PROMOTES_CELL_MOTILITY
# tailed==2
# REACTOME_RAB_GEFS_EXCHANGE_GTP_FOR_GDP_ON_RABS
# tailed==2
# REACTOME_LISTERIA_MONOCYTOGENES_ENTRY_INTO_HOST_CELLS
# tailed==2
# REACTOME_INLA_MEDIATED_ENTRY_OF_LISTERIA_MONOCYTOGENES_INTO_HOST_CELLS
# tailed==2
# REACTOME_PROTEIN_METHYLATION
# tailed==2
# REACTOME_RUNX1_AND_FOXP3_CONTROL_THE_DEVELOPMENT_OF_REGULATORY_T_LYMPHOCYTES_TREGS
# tailed==2
# REACTOME_TRANSCRIPTIONAL_REGULATION_BY_RUNX3
# tailed==2
# REACTOME_TRANSCRIPTIONAL_REGULATION_BY_RUNX2
# tailed==2
# REACTOME_TRANSCRIPTIONAL_REGULATION_BY_RUNX1
# tailed==2
# REACTOME_RUNX1_REGULATES_ESTROGEN_RECEPTOR_MEDIATED_TRANSCRIPTION
# tailed==2
# REACTOME_REGULATION_OF_RUNX1_EXPRESSION_AND_ACTIVITY
# tailed==2
# REACTOME_RECEPTOR_MEDIATED_MITOPHAGY
# tailed==2
# REACTOME_DIGESTION
# tailed==2
# REACTOME_RUNX1_REGULATES_EXPRESSION_OF_COMPONENTS_OF_TIGHT_JUNCTIONS
# tailed==2
# REACTOME_RUNX1_REGULATES_GENES_INVOLVED_IN_MEGAKARYOCYTE_DIFFERENTIATION_AND_PLATELET_FUNCTION
# tailed==2
# REACTOME_ARYL_HYDROCARBON_RECEPTOR_SIGNALLING
# tailed==2
# REACTOME_ESR_MEDIATED_SIGNALING
# tailed==2
# REACTOME_RUNX1_REGULATES_TRANSCRIPTION_OF_GENES_INVOLVED_IN_DIFFERENTIATION_OF_HSCS
# tailed==2
# REACTOME_RUNX1_REGULATES_TRANSCRIPTION_OF_GENES_INVOLVED_IN_DIFFERENTIATION_OF_KERATINOCYTES
# tailed==2
# REACTOME_RUNX1_INTERACTS_WITH_CO_FACTORS_WHOSE_PRECISE_EFFECT_ON_RUNX1_TARGETS_IS_NOT_KNOWN
# tailed==2
# REACTOME_RUNX1_REGULATES_TRANSCRIPTION_OF_GENES_INVOLVED_IN_BCR_SIGNALING
# tailed==2
# REACTOME_RUNX1_REGULATES_TRANSCRIPTION_OF_GENES_INVOLVED_IN_DIFFERENTIATION_OF_MYELOID_CELLS
# tailed==2
# REACTOME_RUNX1_REGULATES_TRANSCRIPTION_OF_GENES_INVOLVED_IN_INTERLEUKIN_SIGNALING
# tailed==2
# REACTOME_RUNX1_REGULATES_TRANSCRIPTION_OF_GENES_INVOLVED_IN_WNT_SIGNALING
# tailed==2
# REACTOME_REGULATION_OF_RUNX2_EXPRESSION_AND_ACTIVITY
# tailed==2
# REACTOME_RUNX2_REGULATES_OSTEOBLAST_DIFFERENTIATION
# tailed==2
# REACTOME_RUNX2_REGULATES_CHONDROCYTE_MATURATION
# tailed==2
# REACTOME_RUNX2_REGULATES_BONE_DEVELOPMENT
# tailed==2
# REACTOME_RUNX2_REGULATES_GENES_INVOLVED_IN_CELL_MIGRATION
# tailed==2
# REACTOME_RUNX3_REGULATES_CDKN1A_TRANSCRIPTION
# tailed==2
# REACTOME_RUNX3_REGULATES_NOTCH_SIGNALING
# tailed==2
# REACTOME_REGULATION_OF_RUNX3_EXPRESSION_AND_ACTIVITY
# tailed==2
# REACTOME_REGULATION_OF_PTEN_MRNA_TRANSLATION
# tailed==2
# REACTOME_REGULATION_OF_PTEN_GENE_TRANSCRIPTION
# tailed==2
# REACTOME_COLLAGEN_CHAIN_TRIMERIZATION
# tailed==2
# REACTOME_COMPETING_ENDOGENOUS_RNAS_CERNAS_REGULATE_PTEN_TRANSLATION
# tailed==2
# REACTOME_REGULATION_OF_PTEN_LOCALIZATION
# tailed==2
# REACTOME_REGULATION_OF_PTEN_STABILITY_AND_ACTIVITY
# tailed==2
# REACTOME_MITOCHONDRIAL_CALCIUM_ION_TRANSPORT
# tailed==2
# REACTOME_RUNX3_REGULATES_IMMUNE_RESPONSE_AND_CELL_MIGRATION
# tailed==2
# REACTOME_CRISTAE_FORMATION
# tailed==2
# REACTOME_PROCESSING_OF_SMDT1
# tailed==2
# REACTOME_GENE_AND_PROTEIN_EXPRESSION_BY_JAK_STAT_SIGNALING_AFTER_INTERLEUKIN_12_STIMULATION
# tailed==2
# REACTOME_RUNX3_REGULATES_WNT_SIGNALING
# tailed==2
# REACTOME_NEDDYLATION
# tailed==2
# REACTOME_RUNX3_REGULATES_YAP1_MEDIATED_TRANSCRIPTION
# tailed==2
# REACTOME_RUNX3_REGULATES_P14_ARF
# tailed==2
# REACTOME_RUNX3_REGULATES_BCL2L11_BIM_TRANSCRIPTION
# tailed==2
# REACTOME_TRANSCRIPTIONAL_REGULATION_BY_E2F6
# tailed==2
# REACTOME_CELLULAR_RESPONSES_TO_EXTERNAL_STIMULI
# tailed==2
# REACTOME_CARBOXYTERMINAL_POST_TRANSLATIONAL_MODIFICATIONS_OF_TUBULIN
# tailed==2
# REACTOME_NUCLEOBASE_CATABOLISM
# tailed==2
# REACTOME_NUCLEOBASE_BIOSYNTHESIS
# tailed==2
# REACTOME_NUCLEOTIDE_SALVAGE
# tailed==2
# REACTOME_METABOLISM_OF_STEROIDS
# tailed==2
# REACTOME_INTESTINAL_ABSORPTION
# No hits. Skipping Term.
# REACTOME_TYROSINE_CATABOLISM
# tailed==2
# REACTOME_PHENYLALANINE_AND_TYROSINE_METABOLISM
# tailed==2
# REACTOME_ASPARTATE_AND_ASPARAGINE_METABOLISM
# tailed==2
# REACTOME_DIGESTION_AND_ABSORPTION
# tailed==2
# REACTOME_CHYLOMICRON_ASSEMBLY
# tailed==2
# REACTOME_ASSEMBLY_OF_ACTIVE_LPL_AND_LIPC_LIPASE_COMPLEXES
# tailed==2
# REACTOME_HDL_ASSEMBLY
# tailed==2
# REACTOME_PLASMA_LIPOPROTEIN_ASSEMBLY
# tailed==2
# REACTOME_PLASMA_LIPOPROTEIN_REMODELING
# tailed==2
# REACTOME_CHYLOMICRON_REMODELING
# No hits. Skipping Term.
# REACTOME_HDL_CLEARANCE
# tailed==2
# REACTOME_CHYLOMICRON_CLEARANCE
# tailed==2
# REACTOME_LDL_CLEARANCE
# tailed==2
# REACTOME_PLASMA_LIPOPROTEIN_CLEARANCE
# tailed==2
# REACTOME_VLDL_CLEARANCE
# tailed==2
# REACTOME_HDL_REMODELING
# tailed==2
# REACTOME_PHENYLALANINE_METABOLISM
# tailed==2
# REACTOME_GLUTAMATE_AND_GLUTAMINE_METABOLISM
# tailed==2
# REACTOME_LIPID_PARTICLE_ORGANIZATION
# tailed==2
# REACTOME_G_BETA_GAMMA_SIGNALLING_THROUGH_CDC42
# tailed==2
# REACTOME_FATTY_ACID_METABOLISM
# tailed==2
# REACTOME_METABOLISM_OF_COFACTORS
# tailed==2
# REACTOME_TRIGLYCERIDE_METABOLISM
# tailed==2
# REACTOME_GLYCOGEN_METABOLISM
# tailed==2
# REACTOME_INTERLEUKIN_15_SIGNALING
# tailed==2
# REACTOME_OAS_ANTIVIRAL_RESPONSE
# tailed==2
# REACTOME_INTERLEUKIN_35_SIGNALLING
# tailed==2
# REACTOME_INTERLEUKIN_9_SIGNALING
# tailed==2
# REACTOME_TRANSCRIPTIONAL_REGULATION_BY_MECP2
# tailed==2
# REACTOME_SIGNALING_BY_NTRK2_TRKB
# tailed==2
# REACTOME_SIGNALING_BY_ERYTHROPOIETIN
# tailed==2
# REACTOME_INTEGRIN_SIGNALING
# tailed==2
# REACTOME_INTRACELLULAR_SIGNALING_BY_SECOND_MESSENGERS
# tailed==2
# REACTOME_SIGNALING_BY_NUCLEAR_RECEPTORS
# tailed==2
# REACTOME_SIGNALING_BY_RECEPTOR_TYROSINE_KINASES
# tailed==2
# REACTOME_SIGNALING_BY_TGF_BETA_FAMILY_MEMBERS
# tailed==2
# REACTOME_RAB_REGULATION_OF_TRAFFICKING
# tailed==2
# REACTOME_INTERLEUKIN_37_SIGNALING
# tailed==2
# REACTOME_EXTRA_NUCLEAR_ESTROGEN_SIGNALING
# tailed==2
# REACTOME_ER_QUALITY_CONTROL_COMPARTMENT_ERQC
# tailed==2
# REACTOME_REGULATION_OF_EXPRESSION_OF_SLITS_AND_ROBOS
# tailed==2
# REACTOME_ROBO_RECEPTORS_BIND_AKAP5
# tailed==2
# REACTOME_INTERLEUKIN_18_SIGNALING
# tailed==2
# REACTOME_NOTCH3_ACTIVATION_AND_TRANSMISSION_OF_SIGNAL_TO_THE_NUCLEUS
# tailed==2
# REACTOME_NOTCH3_INTRACELLULAR_DOMAIN_REGULATES_TRANSCRIPTION
# tailed==2
# REACTOME_NOTCH4_INTRACELLULAR_DOMAIN_REGULATES_TRANSCRIPTION
# tailed==2
# REACTOME_NOTCH4_ACTIVATION_AND_TRANSMISSION_OF_SIGNAL_TO_THE_NUCLEUS
# tailed==2
# REACTOME_TLR3_MEDIATED_TICAM1_DEPENDENT_PROGRAMMED_CELL_DEATH
# tailed==2
# REACTOME_TICAM1_DEPENDENT_ACTIVATION_OF_IRF3_IRF7
# tailed==2
# REACTOME_TICAM1_TRAF6_DEPENDENT_INDUCTION_OF_TAK1_COMPLEX
# tailed==2
# REACTOME_INTERLEUKIN_36_PATHWAY
# tailed==2
# REACTOME_NONCANONICAL_ACTIVATION_OF_NOTCH3
# tailed==2
# REACTOME_ESTROGEN_DEPENDENT_GENE_EXPRESSION
# tailed==2
# REACTOME_BIOSYNTHESIS_OF_SPECIALIZED_PRORESOLVING_MEDIATORS_SPMS
# tailed==2
# REACTOME_BIOSYNTHESIS_OF_EPA_DERIVED_SPMS
# tailed==2
# REACTOME_BIOSYNTHESIS_OF_MARESINS
# tailed==2
# REACTOME_INTERLEUKIN_2_SIGNALING
# tailed==2
# REACTOME_INTERLEUKIN_12_SIGNALING
# tailed==2
# REACTOME_INTERLEUKIN_1_SIGNALING
# tailed==2
# REACTOME_INTERLEUKIN_23_SIGNALING
# tailed==2
# REACTOME_INTERLEUKIN_27_SIGNALING
# tailed==2
# REACTOME_INTERLEUKIN_21_SIGNALING
# tailed==2
# REACTOME_LOSS_OF_MECP2_BINDING_ABILITY_TO_THE_NCOR_SMRT_COMPLEX
# tailed==2
# REACTOME_REGULATION_OF_MECP2_EXPRESSION_AND_ACTIVITY
# tailed==2
# REACTOME_MECP2_REGULATES_NEURONAL_RECEPTORS_AND_CHANNELS
# tailed==2
# REACTOME_MECP2_REGULATES_TRANSCRIPTION_OF_NEURONAL_LIGANDS
# tailed==2
# REACTOME_MECP2_REGULATES_TRANSCRIPTION_FACTORS
# tailed==2
# REACTOME_ACTIVATED_NTRK2_SIGNALS_THROUGH_RAS
# tailed==2
# REACTOME_ERYTHROPOIETIN_ACTIVATES_PHOSPHOINOSITIDE_3_KINASE_PI3K
# tailed==2
# REACTOME_ERYTHROPOIETIN_ACTIVATES_PHOSPHOLIPASE_C_GAMMA_PLCG
# tailed==2
# REACTOME_ERYTHROPOIETIN_ACTIVATES_STAT5
# tailed==2
# REACTOME_ERYTHROPOIETIN_ACTIVATES_RAS
# tailed==2
# REACTOME_BIOSYNTHESIS_OF_MARESIN_LIKE_SPMS
# No hits. Skipping Term.
# REACTOME_ACTIVATED_NTRK2_SIGNALS_THROUGH_PI3K
# tailed==2
# REACTOME_ACTIVATED_NTRK2_SIGNALS_THROUGH_FRS2_AND_FRS3
# tailed==2
# REACTOME_ACTIVATED_NTRK2_SIGNALS_THROUGH_FYN
# tailed==2
# REACTOME_NTRK2_ACTIVATES_RAC1
# tailed==2
# REACTOME_ACTIVATED_NTRK2_SIGNALS_THROUGH_CDK5
# tailed==2
# REACTOME_PEROXISOMAL_PROTEIN_IMPORT
# tailed==2
# REACTOME_TYSND1_CLEAVES_PEROXISOMAL_PROTEINS
# tailed==2
# REACTOME_BLOOD_GROUP_SYSTEMS_BIOSYNTHESIS
# tailed==2
# REACTOME_SIGNALING_BY_NTRK3_TRKC
# tailed==2
# REACTOME_ACTIVATED_NTRK3_SIGNALS_THROUGH_RAS
# tailed==2
# REACTOME_INTERLEUKIN_RECEPTOR_SHC_SIGNALING
# tailed==2
# REACTOME_NONSENSE_MEDIATED_DECAY_NMD
# tailed==2
# REACTOME_TRAF6_MEDIATED_NF_KB_ACTIVATION
# tailed==2
# REACTOME_NF_KB_ACTIVATION_THROUGH_FADD_RIP_1_PATHWAY_MEDIATED_BY_CASPASE_8_AND_10
# tailed==2
# REACTOME_NEGATIVE_REGULATORS_OF_DDX58_IFIH1_SIGNALING
# tailed==2
# REACTOME_IRAK2_MEDIATED_ACTIVATION_OF_TAK1_COMPLEX
# tailed==2
# REACTOME_TRAF6_MEDIATED_INDUCTION_OF_TAK1_COMPLEX_WITHIN_TLR4_COMPLEX
# tailed==2
# REACTOME_MOLYBDENUM_COFACTOR_BIOSYNTHESIS
# tailed==2
# REACTOME_ACTIVATED_NTRK3_SIGNALS_THROUGH_PI3K
# tailed==2
# REACTOME_CLASS_I_PEROXISOMAL_MEMBRANE_PROTEIN_IMPORT
# tailed==2
# REACTOME_NEGATIVE_REGULATION_OF_NOTCH4_SIGNALING
# tailed==2
# REACTOME_PROTEIN_LOCALIZATION
# tailed==2
# REACTOME_INSERTION_OF_TAIL_ANCHORED_PROTEINS_INTO_THE_ENDOPLASMIC_RETICULUM_MEMBRANE
# tailed==2
# REACTOME_ASSEMBLY_AND_CELL_SURFACE_PRESENTATION_OF_NMDA_RECEPTORS
# tailed==2
# REACTOME_AUTOPHAGY
# tailed==2
# REACTOME_LIPOPHAGY
# tailed==2
# REACTOME_CHAPERONE_MEDIATED_AUTOPHAGY
# tailed==2
# REACTOME_FOXO_MEDIATED_TRANSCRIPTION
# tailed==2
# REACTOME_REGULATION_OF_LOCALIZATION_OF_FOXO_TRANSCRIPTION_FACTORS
# tailed==2
# REACTOME_FOXO_MEDIATED_TRANSCRIPTION_OF_CELL_DEATH_GENES
# tailed==2
# REACTOME_FOXO_MEDIATED_TRANSCRIPTION_OF_OXIDATIVE_STRESS_METABOLIC_AND_NEURONAL_GENES
# tailed==2
# REACTOME_LATE_ENDOSOMAL_MICROAUTOPHAGY
# tailed==2
# REACTOME_TRANSCRIPTIONAL_REGULATION_OF_GRANULOPOIESIS
# tailed==2
# REACTOME_NEGATIVE_REGULATION_OF_NMDA_RECEPTOR_MEDIATED_NEURONAL_TRANSMISSION
# tailed==2
# REACTOME_REGULATION_OF_FOXO_TRANSCRIPTIONAL_ACTIVITY_BY_ACETYLATION
# tailed==2
# REACTOME_FOXO_MEDIATED_TRANSCRIPTION_OF_CELL_CYCLE_GENES
# tailed==2
# REACTOME_ACTIVATION_OF_RAC1_DOWNSTREAM_OF_NMDARS
# tailed==2
# REACTOME_ACTIVATION_OF_AMPK_DOWNSTREAM_OF_NMDARS
# tailed==2
# REACTOME_LONG_TERM_POTENTIATION
# tailed==2
# REACTOME_REGULATION_OF_GLYCOLYSIS_BY_FRUCTOSE_2_6_BISPHOSPHATE_METABOLISM
# tailed==2
# REACTOME_ESTROGEN_STIMULATED_SIGNALING_THROUGH_PRKCZ
# tailed==2
# REACTOME_ESTROGEN_DEPENDENT_NUCLEAR_EVENTS_DOWNSTREAM_OF_ESR_MEMBRANE_SIGNALING
# tailed==2
# REACTOME_STAT5_ACTIVATION
# tailed==2
# REACTOME_N_GLYCAN_TRIMMING_AND_ELONGATION_IN_THE_CIS_GOLGI
# tailed==2
# REACTOME_REACTIONS_SPECIFIC_TO_THE_COMPLEX_N_GLYCAN_SYNTHESIS_PATHWAY
# tailed==2
# REACTOME_AMYLOID_FIBER_FORMATION
# tailed==2
# REACTOME_SERINE_BIOSYNTHESIS
# tailed==2
# REACTOME_ANTIGEN_ACTIVATES_B_CELL_RECEPTOR_BCR_LEADING_TO_GENERATION_OF_SECOND_MESSENGERS
# tailed==2
# REACTOME_RECOGNITION_AND_ASSOCIATION_OF_DNA_GLYCOSYLASE_WITH_SITE_CONTAINING_AN_AFFECTED_PURINE
# tailed==2
# REACTOME_ELECTRIC_TRANSMISSION_ACROSS_GAP_JUNCTIONS
# tailed==2
# REACTOME_SIGNALING_BY_ERBB2_IN_CANCER
# tailed==2
# REACTOME_ERYTHROCYTES_TAKE_UP_CARBON_DIOXIDE_AND_RELEASE_OXYGEN
# tailed==2
# REACTOME_EUKARYOTIC_TRANSLATION_ELONGATION
# tailed==2
# REACTOME_MYD88_INDEPENDENT_TLR4_CASCADE
# tailed==2
# REACTOME_HIV_TRANSCRIPTION_INITIATION
# tailed==2
# REACTOME_HIV_TRANSCRIPTION_ELONGATION
# tailed==2
# REACTOME_THE_FATTY_ACID_CYCLING_MODEL
# tailed==2
# REACTOME_TOLL_LIKE_RECEPTOR_10_TLR10_CASCADE
# tailed==2
# REACTOME_NS1_MEDIATED_EFFECTS_ON_HOST_PATHWAYS
# tailed==2
# REACTOME_REGULATION_OF_GLUCOKINASE_BY_GLUCOKINASE_REGULATORY_PROTEIN
# tailed==2
# REACTOME_APC_C_MEDIATED_DEGRADATION_OF_CELL_CYCLE_PROTEINS
# tailed==2
# REACTOME_POLYMERASE_SWITCHING_ON_THE_C_STRAND_OF_THE_TELOMERE
# tailed==2
# REACTOME_TELOMERE_C_STRAND_SYNTHESIS_INITIATION
# tailed==2
# REACTOME_SNRNP_ASSEMBLY
# tailed==2
# REACTOME_RETINOID_CYCLE_DISEASE_EVENTS
# tailed==2
# REACTOME_SEPARATION_OF_SISTER_CHROMATIDS
# tailed==2
# REACTOME_SIGNALING_BY_NOTCH1_PEST_DOMAIN_MUTANTS_IN_CANCER
# tailed==2
# REACTOME_INITIATION_OF_NUCLEAR_ENVELOPE_NE_REFORMATION
# tailed==2
# REACTOME_CHROMATIN_MODIFYING_ENZYMES
# tailed==2
# REACTOME_LOSS_OF_FUNCTION_OF_SMAD2_3_IN_CANCER
# tailed==2
# REACTOME_RIPK1_MEDIATED_REGULATED_NECROSIS
# tailed==2
# REACTOME_B_WICH_COMPLEX_POSITIVELY_REGULATES_RRNA_EXPRESSION
# tailed==2
# REACTOME_ACTIVATION_OF_ANTERIOR_HOX_GENES_IN_HINDBRAIN_DEVELOPMENT_DURING_EARLY_EMBRYOGENESIS
# tailed==2
# REACTOME_CONSTITUTIVE_SIGNALING_BY_EGFRVIII
# tailed==2
# REACTOME_DEPOSITION_OF_NEW_CENPA_CONTAINING_NUCLEOSOMES_AT_THE_CENTROMERE
# tailed==2
# REACTOME_RAS_SIGNALING_DOWNSTREAM_OF_NF1_LOSS_OF_FUNCTION_VARIANTS
# tailed==2
# REACTOME_CYCLIN_D_ASSOCIATED_EVENTS_IN_G1
# tailed==2
# REACTOME_SIGNALING_BY_PTK6
# tailed==2
# REACTOME_TRANSCRIPTIONAL_REGULATION_BY_VENTX
# tailed==2
# REACTOME_LOSS_OF_FUNCTION_OF_MECP2_IN_RETT_SYNDROME
# tailed==2
# REACTOME_NR1H2_AND_NR1H3_MEDIATED_SIGNALING
# tailed==2
# REACTOME_NR1H2_NR1H3_REGULATE_GENE_EXPRESSION_LINKED_TO_LIPOGENESIS
# tailed==2
# REACTOME_NR1H3_NR1H2_REGULATE_GENE_EXPRESSION_LINKED_TO_CHOLESTEROL_TRANSPORT_AND_EFFLUX
# tailed==2
# REACTOME_NR1H2_NR1H3_REGULATE_GENE_EXPRESSION_TO_LIMIT_CHOLESTEROL_UPTAKE
# tailed==2
# REACTOME_NR1H2_NR1H3_REGULATE_GENE_EXPRESSION_LINKED_TO_TRIGLYCERIDE_LIPOLYSIS_IN_ADIPOSE
# tailed==2
# REACTOME_NGF_STIMULATED_TRANSCRIPTION
# tailed==2
# REACTOME_DISEASES_OF_BASE_EXCISION_REPAIR
# tailed==2
# REACTOME_FLT3_SIGNALING
# tailed==2
# REACTOME_HCMV_INFECTION
# tailed==2
# REACTOME_HCMV_EARLY_EVENTS
# tailed==2
# REACTOME_HCMV_LATE_EVENTS
# tailed==2
# REACTOME_POSTMITOTIC_NUCLEAR_PORE_COMPLEX_NPC_REFORMATION
# tailed==2
# REACTOME_EGR2_AND_SOX10_MEDIATED_INITIATION_OF_SCHWANN_CELL_MYELINATION
# tailed==2
# REACTOME_NR1H2_NR1H3_REGULATE_GENE_EXPRESSION_TO_CONTROL_BILE_ACID_HOMEOSTASIS
# tailed==2
# REACTOME_NR1H2_NR1H3_REGULATE_GENE_EXPRESSION_LINKED_TO_GLUCONEOGENESIS
# tailed==2
# REACTOME_RESPONSE_OF_EIF2AK4_GCN2_TO_AMINO_ACID_DEFICIENCY
# tailed==2
# REACTOME_CONSTITUTIVE_SIGNALING_BY_OVEREXPRESSED_ERBB2
# tailed==2
# REACTOME_SUPPRESSION_OF_APOPTOSIS
# tailed==2
# REACTOME_INFECTION_WITH_MYCOBACTERIUM_TUBERCULOSIS
# tailed==2
# REACTOME_PREVENTION_OF_PHAGOSOMAL_LYSOSOMAL_FUSION
# tailed==2
# REACTOME_MODULATION_BY_MTB_OF_HOST_IMMUNE_SYSTEM
# tailed==2
# REACTOME_SUPPRESSION_OF_PHAGOSOMAL_MATURATION
# tailed==2
# REACTOME_RESPONSE_OF_MTB_TO_PHAGOCYTOSIS
# tailed==2
# REACTOME_AMINO_ACIDS_REGULATE_MTORC1
# tailed==2
# REACTOME_ALPHA_PROTEIN_KINASE_1_SIGNALING_PATHWAY
# tailed==2
# REACTOME_DISEASES_OF_PROGRAMMED_CELL_DEATH
# tailed==2
# REACTOME_AGGREPHAGY
# tailed==2
# REACTOME_RESPONSE_OF_EIF2AK1_HRI_TO_HEME_DEFICIENCY
# tailed==2
# REACTOME_LEISHMANIA_INFECTION
# tailed==2
# REACTOME_ADORA2B_MEDIATED_ANTI_INFLAMMATORY_CYTOKINES_PRODUCTION
# tailed==2
# REACTOME_PURINERGIC_SIGNALING_IN_LEISHMANIASIS_INFECTION
# tailed==2
# REACTOME_CD163_MEDIATING_AN_ANTI_INFLAMMATORY_RESPONSE
# tailed==2
# REACTOME_ANTI_INFLAMMATORY_RESPONSE_FAVOURING_LEISHMANIA_PARASITE_INFECTION
# tailed==2
# REACTOME_SELECTIVE_AUTOPHAGY
# tailed==2
# REACTOME_FCGR3A_MEDIATED_IL10_SYNTHESIS
# tailed==2
# REACTOME_PARASITE_INFECTION
# tailed==2
# REACTOME_KILLING_MECHANISMS
# tailed==2
# REACTOME_LTC4_CYSLTR_MEDIATED_IL4_PRODUCTION
# tailed==2
# REACTOME_PEXOPHAGY
# tailed==2
# REACTOME_SIGNALING_BY_ERBB2_ECD_MUTANTS
# tailed==2
# REACTOME_SEALING_OF_THE_NUCLEAR_ENVELOPE_NE_BY_ESCRT_III
# tailed==2
# REACTOME_SIGNALING_BY_PDGFR_IN_DISEASE
# tailed==2
# REACTOME_SIGNALING_BY_PDGFRA_TRANSMEMBRANE_JUXTAMEMBRANE_AND_KINASE_DOMAIN_MUTANTS
# tailed==2
# REACTOME_SIGNALING_BY_MEMBRANE_TETHERED_FUSIONS_OF_PDGFRA_OR_PDGFRB
# tailed==2
# REACTOME_NERVOUS_SYSTEM_DEVELOPMENT
# tailed==2
# REACTOME_DISEASES_OF_DNA_REPAIR
# tailed==2
# /Users/dolanpt/anaconda3/lib/python3.11/site-packages/statsmodels/stats/multitest.py:177: RuntimeWarning: divide by zero encountered in log1p
#   np.log1p(-pvals))

# %%
pcorr=mult(list(StatResults.pBS))
StatResults['adjPbs']=pcorr[1]
StatResults['sig']=pcorr[0]
StatResults
StatResults.to_csv("WT_RD_37_pBS.csv")
# Out:
# /Users/dolanpt/Library/Python/3.9/lib/python/site-packages/statsmodels/stats/multitest.py:186: RuntimeWarning: divide by zero encountered in log1p
#   np.log1p(-pvals))

# %% [markdown]
# The code below still doesn't work... not sure why. But this would make it faster. Perhaps also vectorize could be useful?

# %%
def f(term):
    DF=pd.DataFrame([term,computeEnrichment(term,data,"b")],index=["term","pBS"]).transpose()
    return(DF)

# %%
if __name__ == '__main__':#Wrapped this f() function in a parallelization to speed up. Can tune pool size for computer. 
    with Pool(5) as p:
        StatResults=pd.concat(p.map(f, [term for term in MSigDB.term.unique() if term.startswith(PREFIX)][1:100]))#Just running on the first 100 to test, runs forever, throws errors
    pcorr=mult(list(StatResults.pBS))
    StatResults['adjPbs']=pcorr[1]
    StatResults['sig']=pcorr[0]
    StatResults
    PVMax.to_csv("PVMax.csv")#name output file approriately
# Out:
# Process SpawnPoolWorker-58:
# Process SpawnPoolWorker-57:
# Process SpawnPoolWorker-60:
# Process SpawnPoolWorker-56:
# Process SpawnPoolWorker-59:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
# AttributeError: Can't get attribute 'f' on <module '__main__' (built-in)>
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'f' on <module '__main__' (built-in)>
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'f' on <module '__main__' (built-in)>
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'f' on <module '__main__' (built-in)>
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'f' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-61:
# Traceback (most recent call last):
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'f' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-62:
# Traceback (most recent call last):
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'f' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-63:
# Traceback (most recent call last):
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'f' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-64:
# Traceback (most recent call last):
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'f' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-65:
# Traceback (most recent call last):
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'f' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-66:
# Traceback (most recent call last):
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'f' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-67:
# Traceback (most recent call last):
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'f' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-68:
# Traceback (most recent call last):
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'f' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-69:
# Traceback (most recent call last):
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'f' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-70:
# Traceback (most recent call last):
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'f' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-71:
# Traceback (most recent call last):
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'f' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-72:
# Traceback (most recent call last):
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'f' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-73:
# Traceback (most recent call last):
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'f' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-74:
# Traceback (most recent call last):
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'f' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-75:
# Traceback (most recent call last):
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/dolanpt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'f' on <module '__main__' (built-in)>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 3
#       1 if __name__ == '__main__':#Wrapped this f() function in a parallelization to speed up. Can tune pool size for computer.
#       2     with Pool(5) as p:
# ----> 3         StatResults=pd.concat(p.map(f, [term for term in MSigDB.term.unique() if term.startswith(PREFIX)][1:100]))
#       4     pcorr=mult(list(StatResults.pBS))
#       5     StatResults['adjPbs']=pcorr[1]
#
# File ~/anaconda3/lib/python3.11/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/anaconda3/lib/python3.11/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File ~/anaconda3/lib/python3.11/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File ~/anaconda3/lib/python3.11/threading.py:622, in Event.wait(self, timeout)
#     620 signaled = self._flag
#     621 if not signaled:
# --> 622     signaled = self._cond.wait(timeout)
#     623 return signaled
#
# File ~/anaconda3/lib/python3.11/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:
